# %% [markdown]
# This notebook includes the calculation of volumetric grid charges and the optimization of empirical household energy consumption with flat and dynamic energy prices for this case.

# %%
### Requirements

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from gurobipy import *

# %% [markdown]
# ### Methods

# %% [markdown]
# The first method is used in the optimization to determine the start and end points of each charging session, as well as the overall charged energy within one session. The second method is used to write the results of the optimization into a dataframe, enabling further analysis.

# %%
#Function to calculate start point, end point, and total energy charged for each charging session
def chargPerUser(load,percent):
    
    #List to store information about charging sessions
    charging_sessions = []
    
    total_energy_charged = 0
    b=False
    b1=False

    #Iterate through all time steps
    for i in range(len(percent)):
        
        #If the plugin hour is not a full hour
        if percent[i] < 1 and percent[i] != 0 and b == False:
            total_energy_charged += load[i] #Add charged energy
            start_index = i #Save the start point
            b = True
            
        #If the plugin hour is a full hour   
        elif percent[i]==1 and percent[i-1]==0:
            total_energy_charged += load[i]
            start_index = i
            b = True
        
        #Full charging hour between plugin and plugout
        elif percent[i] == 1:
            total_energy_charged += load[i]
            b = True
            b1 = True
            
        #Plugout after hours of full charging and the end hour is not a full hour   
        elif percent[i] < 1 and percent[i] != 0 and b == True and b1 == True and percent[i+1] == 0:
            total_energy_charged += load[i]
            end_index = i #Save the end point
            charging_sessions.append({'start_index': start_index, 'end_index': end_index, 'total_energy': total_energy_charged})
            total_energy_charged = 0
            b = False
            b1 = False
            
        #Plugout after no hour of full charging and the end hour is not a full hour 
        elif percent[i] < 1 and percent[i] != 0 and b == True and b1 == False and percent[i+1] == 0:
            total_energy_charged += load[i]
            end_index = i
            charging_sessions.append({'start_index': start_index, 'end_index': end_index, 'total_energy': total_energy_charged})
            total_energy_charged = 0
            b = False
            
        #Plugout in the same hour as plugin
        elif percent[i] == 0 and b == True and b1 == False:
            end_index = start_index
            charging_sessions.append({'start_index': start_index, 'end_index': end_index, 'total_energy': total_energy_charged})
            total_energy_charged = 0
            b = False
        
        #Plugout after hours of full charging and the end hour is a full hour 
        elif percent[i] == 0 and b == True and b1 == True:
            end_index = i-1
            charging_sessions.append({'start_index': start_index, 'end_index': end_index, 'total_energy': total_energy_charged})
            total_energy_charged = 0 
            b = False
            b1 = False
        
        #If no energy is charged or if several not full hours follow each other
        else:
            total_energy_charged += load[i]
            
    return(charging_sessions)

# %%
#Write resluts of optimization in dataframe
def get_results_in_df(variableNames, n_timesteps, model): #  "def name(argumente)" zeigt den Anfang einer Funktion an, die ich später beliebig aufrufen kann
   

    results_df = pd.DataFrame(columns = variableNames, index = [t for t in range(n_timesteps)] )   # Hier wird ein leeres DataFrame erstellt, dass als Spalteneinträge die Namen der Gutobi-variablen hat und als Zeilen die Zeitschritte der Entscheidungsvariablen

    for n in variableNames:                                         #Iteration über alle Zielvariablen
        for t in range(n_timesteps):                                #Iteration über alle Zeitschritte
            VarName = n + f"[{t}]"                                  #Hier wird ein String erstellt, der die Form n[t] hat. Mit diesem wird später die Zielvariable ausgelesen
            try:                                                    #try - except ist eine hilfreiche Methdoe, um Fehler abzufangen. Wenn in der nächsten Zeile ein error passiert, bspw. wegen eines Schreibfehlers in meinen zielvariablen, wird die Funktion nicht abgebrochen sondern weiter ausgeführt.
                results_df.loc[t][n] =  model.getVarByName(VarName).x    #Auslesen der Zielvaribale
            except:
                pass
            
    return results_df

# %% [markdown]
# ### Dictionaries

# %% [markdown]
# The following dictionaries are used to reference column names by indexing:

# %%
#Dictionary for households
hh_dic={1:"SFH3_HH",2:"SFH4_HH",3:"SFH5_HH",4:"SFH7_HH",5:"SFH9_HH",6:"SFH12_HH",7:"SFH14_HH",8:"SFH16_HH",9:"SFH18_HH",10:"SFH19_HH",
        11:"SFH20_HH",12:"SFH21_HH",13:"SFH22_HH",14:"SFH27_HH",15:"SFH28_HH",16:"SFH29_HH",17:"SFH30_HH",18:"SFH32_HH",19:"SFH34_HH",
        20:"SFH36_HH",21:"SFH38_HH",22:"SFH39_HH"}

# %%
#Dictionary for heatpumps
hp_dic={1:"SFH3_HP",2:"SFH4_HP",3:"SFH5_HP",4:"SFH7_HP",5:"SFH9_HP",6:"SFH12_HP",7:"SFH14_HP",8:"SFH16_HP",9:"SFH18_HP",10:"SFH19_HP",
        11:"SFH20_HP",12:"SFH21_HP",13:"SFH22_HP",14:"SFH27_HP",15:"SFH28_HP",16:"SFH29_HP",17:"SFH30_HP",18:"SFH32_HP",19:"SFH34_HP",
        20:"SFH36_HP",21:"SFH38_HP",22:"SFH39_HP"}

# %% [markdown]
# ### Optimization

# %% [markdown]
# The following method describes the optimization of empirical household consumption with volumetric grid charges to minimize total costs. HH consumption remains inflexible. Shifting HP consumption is restricted by a maximum number of blocked time steps (sigma_max) in each interval of length 'length'. The total consumption over an interval must match the empirical consumption within that interval. EV shifting is freely possible between plug-in and plug-out times, as long as the maximum charging power (ev_max) of the wallbox is not surpassed and the charged energy for the session matches the empirical data.

# %%
#Optimization of one householdwith hp flexibility within intervals and flexible ev between plugin and plugout with dynamic energy prices
def optimized_HP_EV(hh, hp, ev_user, peak_ev, flexibility, part, p_flex, p_grid):
    
    l = len(hh)
    l_ev= len(ev_user.columns)//2
    ev_max = peak_ev
    hp_max = max(hp)
    sigma_max = flexibility
    part = part
    
    #1. create Model
    model  = Model("simpleHP")
        

    #2. define Variables
    
    #2.1 hp load over all time steps
    d_hp = model.addVars(l, vtype=GRB.CONTINUOUS, lb=0, ub=hp_max, name="d_hp")
    
    #2.2 procentual hp shifts over all time steps
    sigma = model.addVars(l,vtype=GRB.BINARY, name="sigma")
    
    #2.3 ev charging load over all time steps
    d_ev = model.addVars(l, l_ev, vtype=GRB.CONTINUOUS, lb=0, ub=ev_max, name="d_ev")
    
    #2.4 total consumption over all time steps
    d = model.addVars(l, vtype=GRB.CONTINUOUS, lb=0, name="d")

    #2.5 total ev consupmtion per time step
    #ev = model.addVars(l, vtype=GRB.CONTINUOUS, lb=0, name="ev")
    

    #3. constraints
    
    #3.1 total consumption over all time steps as sum of hp, hh and all evs
    model.addConstrs(d[t] == d_hp[t]+hh[t]+quicksum(d_ev[t,u] for u in range(l_ev)) for t in range(l))
    
    #HP
    #3.2 calculation of hp load
    model.addConstrs(d_hp[t] >= (1-sigma[t])*hp[t] for t in range(l))
    
    #3.3 hp flexibility is restricted to flex_hours through binary variable sigma
    model.addConstrs(quicksum(sigma[k] for k in range(part*i,part*i+part)) <= sigma_max for i in range(l//part))

    #3.4 hp load over time part must at least be empirical hp
    model.addConstrs(quicksum(d_hp[k] for k in range(part*i,part*i+part)) >= quicksum(hp[k] for k in range(part*i,part*i+part)) for i in range(l//part))

    
    #EV
    #iterate through all evs (users) that charge at this garage
    for u in range(l_ev):
        ev = ev_user.iloc[:,u*2]
        ev_perc = ev_user.iloc[:,u*2+1]
        
        #3.5 in every timestep ev power demand must be smaller than ev_max
        model.addConstrs(d_ev[t,u] <= ev_perc[t]*ev_max for t in range(l))
        
        #get for every charging session start and end time and the total charged energy
        charging_sessions=chargPerUser(ev,ev_perc)
        list_length = len(charging_sessions)
        
        #iterate through all charging sessions of one user
        for i in range (list_length):
            start_index = charging_sessions[i]['start_index']
            end_index = charging_sessions[i]['end_index']
            total_energy = charging_sessions[i]['total_energy']
            
            #3.6 the charged power between start and end must be equal to the total charged energy
            model.addConstr(quicksum(d_ev[t,u] for t in range(start_index,end_index+1)) == total_energy)

            
    #4. optimize
    objective_expr = quicksum(d[t] * (p_flex.iloc[t,0]+p_grid) for t in range(l))
    
    #4.1 set the costs as the variable to be minimized
    model.setObjective(objective_expr,GRB.MINIMIZE)

    #4.2 perform optimization
    model.optimize()
    
    #5 return results
    #5.1 get objective value
    cost = model.getObjective().getValue()
    
    #get values for total load d for every hour
    var =["d","d_hp"]
    load_after_shift = get_results_in_df(var,l, model)

    #save values of charging station load in every time step
    ev_df = pd.DataFrame(index=range(l))

    for k in range(l_ev):
        col_name = f'ev_{k}'
        ev_df[col_name] = [d_ev[t, k].x for t in range(l)]
    
    return cost, load_after_shift, ev_df

# %% [markdown]
# ### Read in data

# %% [markdown]
# Read in EV charging data, household and heat pump consumption patterns, maximum charging power of each wallbox, day-ahead market prices, garage IDs as well as the total load in the empirical case. All data has been pre-processed beforehand.

# %%
ev_hourly = pd.read_csv('Hourly_EV_Charging.csv')
hh_hp = pd.read_csv('Hourly_HH_HP.csv')
peak_ev = pd.read_csv('Min_Peak_Load.csv')
p_flex = pd.read_csv('Hourly_Flexible_Prices.csv')
unique_garage = pd.read_csv('Unique_Garage.csv')
load_before_shift = pd.read_csv('load_before_shift.csv',index_col=0)

# %% [markdown]
# Calculate total costs for each household in the baseline scenario with volumetric grid charges and a flat electricity tariff. The combined cost of the grid charges and the electricity tariff is 30.85 cents per kWh.

# %%
cost_before_shift_flat = []
for i in range(len(peak_ev)): #iterate over all HHs
    cost = 0
    for k in range(len(p_flex)): #iterate over all time steps
        cost += load_before_shift.iloc[k,i]*0.3085
    cost_before_shift_flat.append(cost)

# %% [markdown]
# Calculate total costs with dynamic electricity prices but without grid charges. Subtract these costs from the costs of the baseline scenario, and then determine the price per kWh to obtain the amount for the volumetric grid charges.

# %%
cost_before_shift_p_flex = []
for i in range(len(peak_ev)):
    cost = 0
    for k in range(len(p_flex)):
        cost += load_before_shift.iloc[k,i]*p_flex.iloc[k,0]
    cost_before_shift_p_flex.append(cost)

# %%
p_grid_total=sum(cost_before_shift_flat)-sum(cost_before_shift_p_flex)
load_total =sum(load_before_shift.sum())
p_grid = p_grid_total/load_total
p_grid= round(p_grid * 10000) / 10000

# %% [markdown]
# ### Perform optimization

# %%
load_after_shift = pd.DataFrame()
cost_after_shift = []
hp_after_shift = pd.DataFrame()
data = np.zeros((len(hh_hp.index),len(peak_ev))) 
ev_after_shift = pd.DataFrame(data)
kappa = 4

#Iterate over all households
for i in range(len(peak_ev)):
    
    #Select all users per garage
    selected_columns = ev_hourly.filter(regex=f'^{unique_garage.iloc[i,0]}-', axis=1)
    
    #Perform optimization
    cost, load, ev_df = optimized_HP_EV(hh_hp[hh_dic[i+1]],hh_hp[hp_dic[i+1]], selected_columns, peak_ev.iloc[i,0],2,kappa,p_flex,p_grid)

    #calculate ev load after shift
    for k in range(len(ev_df)):
        sum=0
        for j in range(len(ev_df.columns)):
            sum += ev_df.iloc[k,j]
        ev_after_shift.iloc[k,i] = sum
    
        
    #Save total costs
    cost_after_shift.append(cost)
    
    #Store shifted loads per household
    load_after_shift[f"{hh_dic[i+1]}_d"] = load.iloc[:,0]
    hp_after_shift[f"{hh_dic[i+1]}_d"] = load.iloc[:,1]
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-01-31
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 52565 rows, 57024 columns and 118818 nonzeros
# Model fingerprint: 0x25a0e295
# Variable types: 47520 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 4e+01]
# Found heuristic solution: objective 2892.3074636
# Presolve removed 52559 rows and 57016 columns
# Presolve time: 1.26s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 2880.4523290
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Explored 0 nodes (0 simplex iterations) in 1.32 seconds (0.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2880.45 2892.31
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.880452329032e+03, best bound 2.880384013233e+03, gap 0.0024%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101253 rows, 104544 columns and 230731 nonzeros
# Model fingerprint: 0xf7a178ed
# Variable types: 95040 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 5e+01]
# Found heuristic solution: objective 8153.0885574
# Presolve removed 101247 rows and 104536 columns
# Presolve time: 1.29s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 8117.0182265
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Explored 0 nodes (0 simplex iterations) in 1.40 seconds (0.15 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 8117.02 8153.09
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.117018226464e+03, best bound 8.116505497742e+03, gap 0.0063%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 62309 rows, 66528 columns and 143059 nonzeros
# Model fingerprint: 0x9c11a93a
# Variable types: 57024 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 6e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [2e-03, 8e+01]
# Found heuristic solution: objective 6030.8743279
# Presolve removed 62303 rows and 66520 columns
# Presolve time: 1.23s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 5981.2045369
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.30 seconds (0.11 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 5981.2 6030.87
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.981204536934e+03, best bound 5.981204536934e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 33470 rows, 38016 columns and 79922 nonzeros
# Model fingerprint: 0x85801142
# Variable types: 28512 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e-02, 2e+01]
# Found heuristic solution: objective 3166.6999201
# Presolve removed 33464 rows and 38008 columns
# Presolve time: 1.15s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 3143.9506600
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.20 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3143.95 3166.7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.143950659964e+03, best bound 3.143950659964e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 33282 rows, 38016 columns and 76287 nonzeros
# Model fingerprint: 0xcc8e2b7c
# Variable types: 28512 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 3e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 6e+01]
# Found heuristic solution: objective 4397.5142595
# Presolve removed 33276 rows and 38008 columns
# Presolve time: 1.15s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 4375.4967363
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.19 seconds (0.07 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 4375.5 4397.51
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.375496736343e+03, best bound 4.375496736343e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42859 rows, 47520 columns and 96184 nonzeros
# Model fingerprint: 0x5d7a51d2
# Variable types: 38016 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 7e+01]
# Found heuristic solution: objective 3146.8994535
# Presolve removed 42853 rows and 47512 columns
# Presolve time: 1.18s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 3131.9576996
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.23 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3131.96 3146.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.131957699587e+03, best bound 3.131957699587e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 52449 rows, 57024 columns and 117276 nonzeros
# Model fingerprint: 0xf7b0c24f
# Variable types: 47520 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 9e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 9e+00]
#   RHS range        [1e-02, 7e+01]
# Found heuristic solution: objective 5201.0774355
# Presolve removed 52443 rows and 57016 columns
# Presolve time: 1.60s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 5120.7618162
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Explored 0 nodes (0 simplex iterations) in 1.63 seconds (0.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 5120.76 5201.08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.120761816151e+03, best bound 5.120305073049e+03, gap 0.0089%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42859 rows, 47520 columns and 96155 nonzeros
# Model fingerprint: 0x29f7c9b8
# Variable types: 38016 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 7e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 2e+01]
# Found heuristic solution: objective 2188.6120934
# Presolve removed 42853 rows and 47512 columns
# Presolve time: 1.58s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 2173.4678880
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.62 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2173.47 2188.61
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.173467887970e+03, best bound 2.173467887970e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 71496 rows, 76032 columns and 154944 nonzeros
# Model fingerprint: 0x962cc3a1
# Variable types: 66528 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 8e+01]
# Found heuristic solution: objective 2749.9891377
# Presolve removed 71490 rows and 76024 columns
# Presolve time: 1.73s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 2747.6001587
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.78 seconds (0.11 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2747.6 2749.99
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.747600158659e+03, best bound 2.747600158659e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42936 rows, 47520 columns and 97533 nonzeros
# Model fingerprint: 0x1a46579b
# Variable types: 38016 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 3e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 7e+01]
# Found heuristic solution: objective 2747.8014455
# Presolve removed 42930 rows and 47512 columns
# Presolve time: 1.59s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 2742.3563642
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Explored 0 nodes (0 simplex iterations) in 1.64 seconds (0.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2742.36 2747.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.742356364184e+03, best bound 2.742108643397e+03, gap 0.0090%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42892 rows, 47520 columns and 96512 nonzeros
# Model fingerprint: 0x81a5968b
# Variable types: 38016 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+01]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 1e+01]
#   RHS range        [7e-02, 6e+01]
# Found heuristic solution: objective 7138.1726707
# Presolve removed 42886 rows and 47512 columns
# Presolve time: 1.58s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 6981.0918027
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.63 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 6981.09 7138.17
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.981091802688e+03, best bound 6.981091802688e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42944 rows, 47520 columns and 98374 nonzeros
# Model fingerprint: 0x5857cfb9
# Variable types: 38016 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 6e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [6e-02, 2e+01]
# Found heuristic solution: objective 3371.2307233
# Presolve removed 42938 rows and 47512 columns
# Presolve time: 1.62s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 3341.0628309
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.67 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3341.06 3371.23
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.341062830941e+03, best bound 3.341062830941e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42897 rows, 47520 columns and 98782 nonzeros
# Model fingerprint: 0xa929a3a1
# Variable types: 38016 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e-02, 2e+01]
# Found heuristic solution: objective 5233.6860884
# Presolve removed 42891 rows and 47512 columns
# Presolve time: 1.56s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 5153.4232057
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Explored 0 nodes (0 simplex iterations) in 1.61 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 5153.42 5233.69
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.153423205660e+03, best bound 5.153040372235e+03, gap 0.0074%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 33372 rows, 38016 columns and 77893 nonzeros
# Model fingerprint: 0x90e28db0
# Variable types: 28512 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [5e-04, 4e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [5e-04, 3e+01]
# Found heuristic solution: objective 1527.8279340
# Presolve removed 33366 rows and 38008 columns
# Presolve time: 1.59s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 1521.3133738
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.63 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1521.31 1527.83
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.521313373799e+03, best bound 1.521313373799e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 33334 rows, 38016 columns and 77003 nonzeros
# Model fingerprint: 0xad9cbe62
# Variable types: 28512 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e-02, 4e+01]
# Found heuristic solution: objective 3998.5852067
# Presolve removed 33328 rows and 38008 columns
# Presolve time: 1.61s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 3933.2135078
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.65 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3933.21 3998.59
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.933213507767e+03, best bound 3.933213507767e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 62066 rows, 66528 columns and 137168 nonzeros
# Model fingerprint: 0x1a1a9696
# Variable types: 57024 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 5e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [6e-04, 3e+01]
# Found heuristic solution: objective 2508.5190319
# Presolve removed 62060 rows and 66520 columns
# Presolve time: 1.67s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 2492.2715811
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.73 seconds (0.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2492.27 2508.52
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.492271581105e+03, best bound 2.492271581105e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 61865 rows, 66528 columns and 134482 nonzeros
# Model fingerprint: 0x1e8625de
# Variable types: 57024 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 5e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [6e-04, 4e+01]
# Found heuristic solution: objective 1780.9729894
# Presolve removed 61859 rows and 66520 columns
# Presolve time: 1.63s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 1771.9596498
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.69 seconds (0.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1771.96 1780.97
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.771959649764e+03, best bound 1.771959649764e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 52460 rows, 57024 columns and 117352 nonzeros
# Model fingerprint: 0x9b64096a
# Variable types: 47520 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 4e+01]
# Found heuristic solution: objective 2537.2103447
# Presolve removed 52454 rows and 57016 columns
# Presolve time: 1.64s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 2525.8741908
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.69 seconds (0.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2525.87 2537.21
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.525874190797e+03, best bound 2.525874190797e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 33290 rows, 38016 columns and 76372 nonzeros
# Model fingerprint: 0x5dc40ba7
# Variable types: 28512 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 6e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e-03, 3e+01]
# Found heuristic solution: objective 4663.6334721
# Presolve removed 33284 rows and 38008 columns
# Presolve time: 1.60s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 4590.5508684
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.63 seconds (0.07 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 4590.55 4663.63
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.590550868433e+03, best bound 4.590550868433e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 33297 rows, 38016 columns and 76903 nonzeros
# Model fingerprint: 0x67e1dcab
# Variable types: 28512 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 6e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [9e-04, 6e+01]
# Found heuristic solution: objective 1896.8240121
# Presolve removed 33291 rows and 38008 columns
# Presolve time: 1.66s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 1885.9919036
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Explored 0 nodes (0 simplex iterations) in 1.71 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1885.99 1896.82
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.885991903572e+03, best bound 1.885846317143e+03, gap 0.0077%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 52337 rows, 57024 columns and 115344 nonzeros
# Model fingerprint: 0x535e3ca4
# Variable types: 47520 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 7e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e-02, 5e+01]
# Found heuristic solution: objective 3555.9606617
# Presolve removed 52331 rows and 57016 columns
# Presolve time: 1.69s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 3502.2475447
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.74 seconds (0.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3502.25 3555.96
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.502247544709e+03, best bound 3.502247544709e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 33276 rows, 38016 columns and 76158 nonzeros
# Model fingerprint: 0xbc51f7f7
# Variable types: 28512 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 2e+01]
# Found heuristic solution: objective 3463.1657906
# Presolve removed 33270 rows and 38008 columns
# Presolve time: 1.67s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 3373.9643949
# Variable types: 4 continuous, 4 integer (4 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.72 seconds (0.07 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3373.96 3463.17
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.373964394947e+03, best bound 3.373964394947e+03, gap 0.0000%

# %% [markdown]
# #### Save Data

# %%
#save as a dataframe
#cost_before_shift_df = pd.DataFrame(cost_before_shift_fix, columns=['cost_before_shift'])
#cost_after_shift_df = pd.DataFrame(cost_after_shift, columns=['cost_after_shift'])

#ev_after_shift.to_csv('ev_after_shift_blocking_4kappa.csv')
#hp_after_shift.to_csv('hp_after_shift_blocking_kappa.csv')
#cost_before_shift_df.to_csv('cost_before_shift.csv')
#cost_after_shift_df.to_csv('cost_after_shift_blocking_2kappa.csv')
#load_after_shift.to_csv('load_after_shift_blocking_2kappa.csv')

# %%
result = [x - y for x, y in zip(cost_after_shift, cost_before_shift_p_grid)]
result
# Out:
# [17.68509356859431,
#  22.278168017235657,
#  39.29449173227658,
#  7.2507030599063,
#  9.925207203974423,
#  7.078037913924618,
#  -12.224461139391678,
#  -15.393073019759413,
#  14.818271743792593,
#  9.536601524050639,
#  5.444412889056366,
#  -13.45288293141084,
#  -11.108031488194683,
#  -9.994040144506698,
#  -23.721718042303564,
#  -5.472056363511911,
#  -7.936552693612839,
#  -0.8740796734555261,
#  -8.137998175602661,
#  -14.598605432842305,
#  -4.335095348141294,
#  -0.1915390059020865]

# %%
(load_before_shift-load_after_shift).abs().sum()
# Out:
# SFH3_HH_d      5865.408585
# SFH4_HH_d     18141.391262
# SFH5_HH_d     10566.966795
# SFH7_HH_d      3797.220415
# SFH9_HH_d       662.625836
# SFH12_HH_d     3128.280851
# SFH14_HH_d     4291.073139
# SFH16_HH_d      937.460273
# SFH18_HH_d     3680.282429
# SFH19_HH_d     2865.936546
# SFH20_HH_d     2255.444749
# SFH21_HH_d     1896.784316
# SFH22_HH_d     2125.612672
# SFH27_HH_d       897.40521
# SFH28_HH_d      863.849029
# SFH29_HH_d     3229.364419
# SFH30_HH_d     1599.341856
# SFH32_HH_d     2423.541034
# SFH34_HH_d      367.682308
# SFH36_HH_d      380.812037
# SFH38_HH_d     1243.430147
# SFH39_HH_d      186.378107
# dtype: object

# %%
load_before_shift.sum()
# Out:
# SFH3_HH_d      9336.960548
# SFH4_HH_d     26311.242225
# SFH5_HH_d     19388.021189
# SFH7_HH_d     10191.088039
# SFH9_HH_d     14183.133667
# SFH12_HH_d    10152.212965
# SFH14_HH_d    16598.903780
# SFH16_HH_d     7045.276784
# SFH18_HH_d     8906.321422
# SFH19_HH_d     8889.323709
# SFH20_HH_d    22629.146848
# SFH21_HH_d    10830.025384
# SFH22_HH_d    16704.775383
# SFH27_HH_d     4931.323740
# SFH28_HH_d    12749.476524
# SFH29_HH_d     8078.676114
# SFH30_HH_d     5743.791409
# SFH32_HH_d     8187.598674
# SFH34_HH_d    14880.229719
# SFH36_HH_d     6113.425944
# SFH38_HH_d    11352.504197
# SFH39_HH_d    10936.675510
# dtype: float64

# %%
cost_before_shift_fix
# Out:
# [2880.452329032419,
#  8117.018226463992,
#  5981.204536933995,
#  3143.95065996387,
#  4375.496736342777,
#  3131.9576995874654,
#  5120.761816151057,
#  2173.467887969717,
#  2747.60015865926,
#  2742.356364183874,
#  6981.091802688233,
#  3341.0628309405997,
#  5153.423205659861,
#  1521.3133737985136,
#  3933.2135077665084,
#  2492.2715811045623,
#  1771.959649763647,
#  2525.8741907972835,
#  4590.550868433328,
#  1885.9919035715739,
#  3502.2475447088523,
#  3373.9643949472847]

# %%
max_load=[]
for i in range(len(peak_ev)):
    max_load.append(load_before_shift.iloc[:,i].max())

# %%
max_load
# Out:
# [8.443513571159373,
#  13.757084544675845,
#  14.269770577816413,
#  7.4620650434405,
#  8.882654361335577,
#  12.28462129656588,
#  10.581827354995545,
#  8.497970897002398,
#  13.05775670697222,
#  12.026470206534732,
#  14.35221600535728,
#  6.119831894983115,
#  8.70217134132085,
#  4.419939951541688,
#  8.48202431678053,
#  11.478737072346776,
#  8.968742716810091,
#  9.044348775086204,
#  8.199570362978967,
#  9.6315659222073,
#  12.20593952535696,
#  9.72902695647606]

# %%
p_fix=np.zeros(25)
for i in range(25):
    p_fix[i]=0.3085
p_grid
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(p_fix, label="fix", color='tab:orange', linewidth=1.0)
ax.plot(p_flex.iloc[24:49,0].reset_index(drop=True)+p_grid, label="dynamic", color='tab:blue', linewidth=1.0)
ax.set_ylabel("Price per kWh")
ax.legend(labels=["fix", "dynamic"], loc="center left", bbox_to_anchor=(0.65, 0.20))
ticks = [i * 6 for i in range(5)]  # 0, 6, 12, 18, 24
labels = ['0:00', '6:00', '12:00', '18:00', '24:00']
ax.set_xticks(ticks)
ax.set_xticklabels(labels)
ax.set_xlabel('Time')
plt.savefig('Prices.png', bbox_inches='tight')
plt.show()
