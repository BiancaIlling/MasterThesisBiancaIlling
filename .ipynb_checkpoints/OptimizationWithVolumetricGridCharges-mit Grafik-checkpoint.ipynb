# %% [markdown]
# This notebook includes the calculation of volumetric grid charges and the optimization of empirical household energy consumption with flat and dynamic energy prices for this case.

# %% [markdown]
# ### Requirements

# %% [markdown]
# Load the necessary packages to complete the optimization.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from gurobipy import *

# %% [markdown]
# ### Methods

# %% [markdown]
# The first method is used in the optimization to determine the start and end points of each charging session, as well as the overall charged energy within one session. The second method is used to write the results of the optimization into a dataframe, enabling further analysis.

# %%
#Function to calculate start point, end point, and total energy charged for each charging session
def chargPerUser(load,percent):
    
    #List to store information about charging sessions
    charging_sessions = []
    
    total_energy_charged = 0
    b=False
    b1=False

    #Iterate through all time steps
    for i in range(len(percent)):
        
        #If the plugin hour is not a full hour
        if percent[i] < 1 and percent[i] != 0 and b == False:
            total_energy_charged += load[i] #Add charged energy
            start_index = i #Save the start point
            b = True
            
        #If the plugin hour is a full hour   
        elif percent[i]==1 and percent[i-1]==0:
            total_energy_charged += load[i]
            start_index = i
            b = True
        
        #Full charging hour between plugin and plugout
        elif percent[i] == 1:
            total_energy_charged += load[i]
            b = True
            b1 = True
            
        #Plugout after hours of full charging and the end hour is not a full hour   
        elif percent[i] < 1 and percent[i] != 0 and b == True and b1 == True and percent[i+1] == 0:
            total_energy_charged += load[i]
            end_index = i #Save the end point
            charging_sessions.append({'start_index': start_index, 'end_index': end_index, 'total_energy': total_energy_charged})
            total_energy_charged = 0
            b = False
            b1 = False
            
        #Plugout after no hour of full charging and the end hour is not a full hour 
        elif percent[i] < 1 and percent[i] != 0 and b == True and b1 == False and percent[i+1] == 0:
            total_energy_charged += load[i]
            end_index = i
            charging_sessions.append({'start_index': start_index, 'end_index': end_index, 'total_energy': total_energy_charged})
            total_energy_charged = 0
            b = False
            
        #Plugout in the same hour as plugin
        elif percent[i] == 0 and b == True and b1 == False:
            end_index = start_index
            charging_sessions.append({'start_index': start_index, 'end_index': end_index, 'total_energy': total_energy_charged})
            total_energy_charged = 0
            b = False
        
        #Plugout after hours of full charging and the end hour is a full hour 
        elif percent[i] == 0 and b == True and b1 == True:
            end_index = i-1
            charging_sessions.append({'start_index': start_index, 'end_index': end_index, 'total_energy': total_energy_charged})
            total_energy_charged = 0 
            b = False
            b1 = False
        
        #If no energy is charged or if several not full hours follow each other
        else:
            total_energy_charged += load[i]
            
    return(charging_sessions)

# %%
#Write resluts of optimization in dataframe
def get_results_in_df(variableNames, n_timesteps, model): #  "def name(argumente)" zeigt den Anfang einer Funktion an, die ich später beliebig aufrufen kann
   

    results_df = pd.DataFrame(columns = variableNames, index = [t for t in range(n_timesteps)] )   # Hier wird ein leeres DataFrame erstellt, dass als Spalteneinträge die Namen der Gutobi-variablen hat und als Zeilen die Zeitschritte der Entscheidungsvariablen

    for n in variableNames:                                         #Iteration über alle Zielvariablen
        for t in range(n_timesteps):                                #Iteration über alle Zeitschritte
            VarName = n + f"[{t}]"                                  #Hier wird ein String erstellt, der die Form n[t] hat. Mit diesem wird später die Zielvariable ausgelesen
            try:                                                    #try - except ist eine hilfreiche Methdoe, um Fehler abzufangen. Wenn in der nächsten Zeile ein error passiert, bspw. wegen eines Schreibfehlers in meinen zielvariablen, wird die Funktion nicht abgebrochen sondern weiter ausgeführt.
                results_df.loc[t][n] =  model.getVarByName(VarName).x    #Auslesen der Zielvaribale
            except:
                pass
            
    return results_df

# %% [markdown]
# ### Dictionaries

# %% [markdown]
# The following dictionaries are used to reference column names by indexing:

# %%
#Dictionary for households
hh_dic={1:"SFH3_HH",2:"SFH4_HH",3:"SFH5_HH",4:"SFH7_HH",5:"SFH9_HH",6:"SFH12_HH",7:"SFH14_HH",8:"SFH16_HH",9:"SFH18_HH",10:"SFH19_HH",
        11:"SFH20_HH",12:"SFH21_HH",13:"SFH22_HH",14:"SFH27_HH",15:"SFH28_HH",16:"SFH29_HH",17:"SFH30_HH",18:"SFH32_HH",19:"SFH34_HH",
        20:"SFH36_HH",21:"SFH38_HH",22:"SFH39_HH"}

# %%
#Dictionary for heatpumps
hp_dic={1:"SFH3_HP",2:"SFH4_HP",3:"SFH5_HP",4:"SFH7_HP",5:"SFH9_HP",6:"SFH12_HP",7:"SFH14_HP",8:"SFH16_HP",9:"SFH18_HP",10:"SFH19_HP",
        11:"SFH20_HP",12:"SFH21_HP",13:"SFH22_HP",14:"SFH27_HP",15:"SFH28_HP",16:"SFH29_HP",17:"SFH30_HP",18:"SFH32_HP",19:"SFH34_HP",
        20:"SFH36_HP",21:"SFH38_HP",22:"SFH39_HP"}

# %% [markdown]
# ### Optimization

# %% [markdown]
# The following method describes the optimization of empirical household consumption with volumetric grid charges to minimize total costs. HH consumption remains inflexible. Shifting HP consumption is restricted by a maximum number of blocked time steps (sigma_max) in each interval of length 'length'. The total consumption over an interval must match the empirical consumption within that interval. EV shifting is freely possible between plug-in and plug-out times, as long as the maximum charging power (ev_max) of the wallbox is not surpassed and the charged energy for the session matches the empirical data.

# %%
#Optimization of one householdwith hp flexibility within intervals and flexible ev between plugin and plugout with dynamic energy prices
def optimized_HP_EV(hh, hp, ev_user, peak_ev, flexibility, part, p_flex, p_grid):
    
    l = len(hh)
    l_ev= len(ev_user.columns)//2
    ev_max = peak_ev
    hp_max = max(hp)
    sigma_max = flexibility
    part = part
    
    #1. create Model
    model  = Model("simpleHP")
        

    #2. define Variables
    
    #2.1 hp load over all time steps
    d_hp = model.addVars(l, vtype=GRB.CONTINUOUS, lb=0, ub=hp_max, name="d_hp")
    
    #2.2 procentual hp shifts over all time steps
    sigma = model.addVars(l,vtype=GRB.BINARY, name="sigma")
    
    #2.3 ev charging load over all time steps
    d_ev = model.addVars(l, l_ev, vtype=GRB.CONTINUOUS, lb=0, ub=ev_max, name="d_ev")
    
    #2.4 total consumption over all time steps
    d = model.addVars(l, vtype=GRB.CONTINUOUS, lb=0, name="d")

    #2.5 total ev consupmtion per time step
    #ev = model.addVars(l, vtype=GRB.CONTINUOUS, lb=0, name="ev")
    

    #3. constraints
    
    #3.1 total consumption over all time steps as sum of hp, hh and all evs
    model.addConstrs(d[t] == d_hp[t]+hh[t]+quicksum(d_ev[t,u] for u in range(l_ev)) for t in range(l))
    
    #HP
    #3.2 calculation of hp load
    model.addConstrs(d_hp[t] >= (1-sigma[t])*hp[t] for t in range(l))
    
    #3.3 hp flexibility is restricted to flex_hours through binary variable sigma
    model.addConstrs(quicksum(sigma[k] for k in range(part*i,part*i+part)) <= sigma_max for i in range(l//part))

    #3.4 hp load over time part must at least be empirical hp
    model.addConstrs(quicksum(d_hp[k] for k in range(part*i,part*i+part)) >= quicksum(hp[k] for k in range(part*i,part*i+part)) for i in range(l//part))

    
    #EV
    #iterate through all evs (users) that charge at this garage
    for u in range(l_ev):
        ev = ev_user.iloc[:,u*2]
        ev_perc = ev_user.iloc[:,u*2+1]
        
        #3.5 in every timestep ev power demand must be smaller than ev_max
        model.addConstrs(d_ev[t,u] <= ev_perc[t]*ev_max for t in range(l))
        
        #get for every charging session start and end time and the total charged energy
        charging_sessions=chargPerUser(ev,ev_perc)
        list_length = len(charging_sessions)
        
        #iterate through all charging sessions of one user
        for i in range (list_length):
            start_index = charging_sessions[i]['start_index']
            end_index = charging_sessions[i]['end_index']
            total_energy = charging_sessions[i]['total_energy']
            
            #3.6 the charged power between start and end must be equal to the total charged energy
            model.addConstr(quicksum(d_ev[t,u] for t in range(start_index,end_index+1)) == total_energy)

            
    #4. optimize
    objective_expr = quicksum(d[t] * (p_flex.iloc[t,0]+p_grid) for t in range(l))
    
    #4.1 set the costs as the variable to be minimized
    model.setObjective(objective_expr,GRB.MINIMIZE)

    #4.2 perform optimization
    model.optimize()
    
    #5 return results
    #5.1 get objective value
    cost = model.getObjective().getValue()
    
    #get values for total load d for every hour
    var =["d","d_hp"]
    load_after_shift = get_results_in_df(var,l, model)

    #save values of charging station load in every time step
    ev_df = pd.DataFrame(index=range(l))

    for k in range(l_ev):
        col_name = f'ev_{k}'
        ev_df[col_name] = [d_ev[t, k].x for t in range(l)]
    
    return cost, load_after_shift, ev_df

# %% [markdown]
# ### Read in data

# %% [markdown]
# Read in EV charging data, household and heat pump consumption patterns, maximum charging power of each wallbox, day-ahead market prices, garage IDs as well as the total load in the empirical case. All data has been pre-processed beforehand.

# %%
ev_hourly = pd.read_csv('Hourly_EV_Charging.csv')
hh_hp = pd.read_csv('Hourly_HH_HP.csv')
peak_ev = pd.read_csv('Min_Peak_Load.csv')
p_flex = pd.read_csv('Hourly_Flexible_Prices.csv')
unique_garage = pd.read_csv('Unique_Garage.csv')
load_before_shift = pd.read_csv('load_before_shift.csv',index_col=0)

# %% [markdown]
# Calculate total costs for each household in the baseline scenario with volumetric grid charges and a flat electricity tariff. The combined cost of the grid charges and the electricity tariff is 30.85 cents per kWh.

# %%
cost_before_shift_flat = []
for i in range(len(peak_ev)): #iterate over all HHs
    cost = 0
    for k in range(len(p_flex)): #iterate over all time steps
        cost += load_before_shift.iloc[k,i]*0.3085
    cost_before_shift_flat.append(cost)

# %% [markdown]
# Calculate total costs with dynamic electricity prices but without grid charges. Subtract these costs from the costs of the baseline scenario, and then determine the price per kWh to obtain the amount for the volumetric grid charges.

# %%
cost_before_shift_p_flex = []
for i in range(len(peak_ev)):
    cost = 0
    for k in range(len(p_flex)):
        cost += load_before_shift.iloc[k,i]*p_flex.iloc[k,0]
    cost_before_shift_p_flex.append(cost)

# %%
p_grid_total=sum(cost_before_shift_flat)-sum(cost_before_shift_p_flex)
load_total =sum(load_before_shift.sum())
p_grid = p_grid_total/load_total
p_grid= round(p_grid * 10000) / 10000

# %% [markdown]
# ### Perform optimization

# %% [markdown]
# Perform optimization for each HH for dynamic energy prices, to determine the new household consumption patterns.

# %%
load_after_shift = pd.DataFrame()
cost_after_shift = []
hp_after_shift = pd.DataFrame()
data = np.zeros((len(hh_hp.index),len(peak_ev))) 
ev_after_shift = pd.DataFrame(data)
kappa = 4 #interval length
sigma_max = 2 #number of blocked time steps allowed in one interval

#Iterate over all households
for i in range(len(peak_ev)):
    
    #Select all users per garage
    selected_columns = ev_hourly.filter(regex=f'^{unique_garage.iloc[i,0]}-', axis=1)
    
    #Perform optimization
    cost, load, ev_df = optimized_HP_EV(hh_hp[hh_dic[i+1]],hh_hp[hp_dic[i+1]], selected_columns, peak_ev.iloc[i,0],sigma_max,kappa,p_flex,p_grid)

    #Calculate ev load after shift
    for k in range(len(ev_df)):
        sum=0
        for j in range(len(ev_df.columns)):
            sum += ev_df.iloc[k,j]
        ev_after_shift.iloc[k,i] = sum
    
        
    #Save total costs
    cost_after_shift.append(cost)
    
    #Store shifted loads per household
    load_after_shift[f"{hh_dic[i+1]}_d"] = load.iloc[:,0]
    hp_after_shift[f"{hh_dic[i+1]}_d"] = load.iloc[:,1]
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-01-31
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 52565 rows, 57024 columns and 118818 nonzeros
# Model fingerprint: 0xf1be6167
# Variable types: 47520 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 4e+01]
# Found heuristic solution: objective 2873.9701928
# Presolve removed 52564 rows and 56952 columns
# Presolve time: 1.67s
# Presolved: 1 rows, 72 columns, 72 nonzeros
# Found heuristic solution: objective 2809.5910150
# Variable types: 72 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.809106e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2809.1060212 2809.10602  0.00%     -    1s
#
# Explored 1 nodes (1 simplex iterations) in 1.70 seconds (0.11 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2809.11 2873.97
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.809106021239e+03, best bound 2.809106021239e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 101253 rows, 104544 columns and 230731 nonzeros
# Model fingerprint: 0x15d69008
# Variable types: 95040 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 5e+01]
# Found heuristic solution: objective 8119.0080914
# Presolve removed 101252 rows and 104374 columns
# Presolve time: 2.01s
# Presolved: 1 rows, 170 columns, 170 nonzeros
# Found heuristic solution: objective 7914.7051722
# Variable types: 170 continuous, 0 integer (0 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 2.06 seconds (0.18 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7914.71 8119.01
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.914705172173e+03, best bound 7.914053291466e+03, gap 0.0082%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 62309 rows, 66528 columns and 143059 nonzeros
# Model fingerprint: 0xbe45379a
# Variable types: 57024 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 6e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [2e-03, 8e+01]
# Found heuristic solution: objective 5992.5173063
# Presolve removed 62308 rows and 66391 columns
# Presolve time: 1.73s
# Presolved: 1 rows, 137 columns, 137 nonzeros
# Found heuristic solution: objective 5832.2508018
# Variable types: 137 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 5.831590e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5831.5897825 5831.58978  0.00%     -    1s
#
# Explored 1 nodes (1 simplex iterations) in 1.78 seconds (0.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 5831.59 5992.52
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.831589782519e+03, best bound 5.831589782519e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 33470 rows, 38016 columns and 79922 nonzeros
# Model fingerprint: 0x75de0967
# Variable types: 28512 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e-02, 2e+01]
# Found heuristic solution: objective 3157.7016788
# Presolve removed 33469 rows and 37886 columns
# Presolve time: 1.63s
# Presolved: 1 rows, 130 columns, 130 nonzeros
# Found heuristic solution: objective 3094.4712717
# Variable types: 130 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 3.093871e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3093.8707394 3093.87074  0.00%     -    1s
#
# Explored 1 nodes (1 simplex iterations) in 1.66 seconds (0.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3093.87 3157.7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.093870739410e+03, best bound 3.093870739410e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 33282 rows, 38016 columns and 76287 nonzeros
# Model fingerprint: 0x11e9d4bc
# Variable types: 28512 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 3e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 6e+01]
# Found heuristic solution: objective 4387.3271522
# Presolve removed 33281 rows and 37976 columns
# Presolve time: 1.60s
# Presolved: 1 rows, 40 columns, 40 nonzeros
# Found heuristic solution: objective 4333.8089106
# Variable types: 40 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 4.333195e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    4333.1949606 4333.19496  0.00%     -    1s
#
# Explored 1 nodes (1 simplex iterations) in 1.63 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 4333.19 4387.33
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.333194960645e+03, best bound 4.333194960645e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42859 rows, 47520 columns and 96184 nonzeros
# Model fingerprint: 0x88470ad1
# Variable types: 38016 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 7e+01]
# Found heuristic solution: objective 3138.0111975
# Presolve removed 42858 rows and 47495 columns
# Presolve time: 1.62s
# Presolved: 1 rows, 25 columns, 25 nonzeros
# Found heuristic solution: objective 3087.5298866
# Variable types: 25 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 3.086767e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3086.7669867 3086.76699  0.00%     -    1s
#
# Explored 1 nodes (1 simplex iterations) in 1.65 seconds (0.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3086.77 3138.01
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.086766986685e+03, best bound 3.086766986685e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 52449 rows, 57024 columns and 117276 nonzeros
# Model fingerprint: 0x9e9493be
# Variable types: 47520 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 9e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 9e+00]
#   RHS range        [1e-02, 7e+01]
# Found heuristic solution: objective 5207.1085674
# Presolve removed 52448 rows and 56921 columns
# Presolve time: 1.82s
# Presolved: 1 rows, 103 columns, 103 nonzeros
# Found heuristic solution: objective 5059.8337150
# Variable types: 103 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 5.059062e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5059.0618687 5059.06187  0.00%     -    1s
#
# Explored 1 nodes (1 simplex iterations) in 1.85 seconds (0.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 5059.06 5207.11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.059061868676e+03, best bound 5.059061868676e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42859 rows, 47520 columns and 96155 nonzeros
# Model fingerprint: 0xa78f115f
# Variable types: 38016 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 7e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 2e+01]
# Found heuristic solution: objective 2203.7549564
# Presolve removed 42858 rows and 47473 columns
# Presolve time: 1.88s
# Presolved: 1 rows, 47 columns, 47 nonzeros
# Found heuristic solution: objective 2168.1023403
# Variable types: 47 continuous, 0 integer (0 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.90 seconds (0.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2168.1 2203.75
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.168102340336e+03, best bound 2.168029070049e+03, gap 0.0034%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 71496 rows, 76032 columns and 154944 nonzeros
# Model fingerprint: 0xdd6c61cf
# Variable types: 66528 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 8e+01]
# Found heuristic solution: objective 2731.7203759
# Presolve removed 71495 rows and 75972 columns
# Presolve time: 1.57s
# Presolved: 1 rows, 60 columns, 60 nonzeros
# Found heuristic solution: objective 2696.1163362
# Variable types: 60 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.695825e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2695.8251728 2695.82517  0.00%     -    1s
#
# Explored 1 nodes (1 simplex iterations) in 1.61 seconds (0.12 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2695.83 2731.72
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.695825172775e+03, best bound 2.695825172775e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42936 rows, 47520 columns and 97533 nonzeros
# Model fingerprint: 0xfb37a49e
# Variable types: 38016 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 3e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 7e+01]
# Found heuristic solution: objective 2737.4246398
# Presolve removed 42935 rows and 47453 columns
# Presolve time: 1.63s
# Presolved: 1 rows, 67 columns, 67 nonzeros
# Found heuristic solution: objective 2702.5032061
# Variable types: 67 continuous, 0 integer (0 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.66 seconds (0.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2702.5 2737.42
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.702503206051e+03, best bound 2.702336512147e+03, gap 0.0062%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42892 rows, 47520 columns and 96512 nonzeros
# Model fingerprint: 0x4bef0da0
# Variable types: 38016 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+01]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 1e+01]
#   RHS range        [7e-02, 6e+01]
# Found heuristic solution: objective 7130.8967151
# Presolve removed 42891 rows and 47451 columns
# Presolve time: 2.19s
# Presolved: 1 rows, 69 columns, 69 nonzeros
# Found heuristic solution: objective 6894.3061461
# Variable types: 69 continuous, 0 integer (0 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 2.22 seconds (0.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 6894.31 7130.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.894306146067e+03, best bound 6.894098757601e+03, gap 0.0030%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42944 rows, 47520 columns and 98374 nonzeros
# Model fingerprint: 0xee42d2c1
# Variable types: 38016 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 6e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [6e-02, 2e+01]
# Found heuristic solution: objective 3384.3581595
# Presolve removed 42943 rows and 47401 columns
# Presolve time: 2.14s
# Presolved: 1 rows, 119 columns, 119 nonzeros
# Found heuristic solution: objective 3316.5543183
# Variable types: 119 continuous, 0 integer (0 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 2.17 seconds (0.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3316.55 3384.36
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.316554318301e+03, best bound 3.316380009807e+03, gap 0.0053%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42897 rows, 47520 columns and 98782 nonzeros
# Model fingerprint: 0xa3005005
# Variable types: 38016 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e-02, 2e+01]
# Found heuristic solution: objective 5242.6379146
# Presolve removed 42896 rows and 47279 columns
# Presolve time: 1.84s
# Presolved: 1 rows, 241 columns, 241 nonzeros
# Found heuristic solution: objective 5103.6487151
# Variable types: 241 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 5.102946e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5102.9456647 5102.94566  0.00%     -    1s
#
# Explored 1 nodes (1 simplex iterations) in 1.87 seconds (0.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 5102.95 5242.64
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.102945664656e+03, best bound 5.102945664656e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 33372 rows, 38016 columns and 77893 nonzeros
# Model fingerprint: 0x9b84aca7
# Variable types: 28512 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [5e-04, 4e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [5e-04, 3e+01]
# Found heuristic solution: objective 1537.4843552
# Presolve removed 33371 rows and 37949 columns
# Presolve time: 1.88s
# Presolved: 1 rows, 67 columns, 67 nonzeros
# Found heuristic solution: objective 1513.4141023
# Variable types: 67 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 1.512945e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1512.9448599 1512.94486  0.00%     -    1s
#
# Explored 1 nodes (1 simplex iterations) in 1.91 seconds (0.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1512.94 1537.48
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.512944859855e+03, best bound 1.512944859855e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 33334 rows, 38016 columns and 77003 nonzeros
# Model fingerprint: 0x5baabfa9
# Variable types: 28512 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e-02, 4e+01]
# Found heuristic solution: objective 4021.8240394
# Presolve removed 33333 rows and 37977 columns
# Presolve time: 2.06s
# Presolved: 1 rows, 39 columns, 39 nonzeros
# Found heuristic solution: objective 3923.6470198
# Variable types: 39 continuous, 0 integer (0 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 2.09 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3923.65 4021.82
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.923647019841e+03, best bound 3.923646985707e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 62066 rows, 66528 columns and 137168 nonzeros
# Model fingerprint: 0x23c29076
# Variable types: 57024 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 5e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [6e-04, 3e+01]
# Found heuristic solution: objective 2510.3390672
# Presolve removed 62065 rows and 66440 columns
# Presolve time: 2.08s
# Presolved: 1 rows, 88 columns, 88 nonzeros
# Found heuristic solution: objective 2458.7984080
# Variable types: 88 continuous, 0 integer (0 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 2.12 seconds (0.12 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2458.8 2510.34
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.458798408036e+03, best bound 2.458634628551e+03, gap 0.0067%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 61865 rows, 66528 columns and 134482 nonzeros
# Model fingerprint: 0x0e0d3346
# Variable types: 57024 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 5e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [6e-04, 4e+01]
# Found heuristic solution: objective 1788.7470111
# Presolve removed 61864 rows and 66477 columns
# Presolve time: 1.76s
# Presolved: 1 rows, 51 columns, 51 nonzeros
# Found heuristic solution: objective 1758.7223163
# Variable types: 51 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 1.758389e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1758.3893034 1758.38930  0.00%     -    1s
#
# Explored 1 nodes (1 simplex iterations) in 1.80 seconds (0.11 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1758.39 1788.75
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.758389303423e+03, best bound 1.758389303423e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 52460 rows, 57024 columns and 117352 nonzeros
# Model fingerprint: 0x1be738a5
# Variable types: 47520 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 4e+01]
# Found heuristic solution: objective 2536.9945120
# Presolve removed 52459 rows and 56950 columns
# Presolve time: 1.73s
# Presolved: 1 rows, 74 columns, 74 nonzeros
# Found heuristic solution: objective 2494.4373215
# Variable types: 74 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 2.493037e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2493.0371695 2493.03717  0.00%     -    1s
#
# Explored 1 nodes (1 simplex iterations) in 1.76 seconds (0.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2493.04 2536.99
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.493037169523e+03, best bound 2.493037169523e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 33290 rows, 38016 columns and 76372 nonzeros
# Model fingerprint: 0x80c9acf7
# Variable types: 28512 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 6e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e-03, 3e+01]
# Found heuristic solution: objective 4671.5056167
# Presolve removed 33289 rows and 37952 columns
# Presolve time: 2.11s
# Presolved: 1 rows, 64 columns, 64 nonzeros
# Found heuristic solution: objective 4558.0752726
# Variable types: 64 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 4.557549e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    4557.5493030 4557.54930  0.00%     -    2s
#
# Explored 1 nodes (1 simplex iterations) in 2.14 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 4557.55 4671.51
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.557549303019e+03, best bound 4.557549303019e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 33297 rows, 38016 columns and 76903 nonzeros
# Model fingerprint: 0x7717cf0e
# Variable types: 28512 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 6e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [9e-04, 6e+01]
# Found heuristic solution: objective 1911.6951109
# Presolve removed 33296 rows and 37950 columns
# Presolve time: 1.98s
# Presolved: 1 rows, 66 columns, 66 nonzeros
# Found heuristic solution: objective 1886.2584812
# Variable types: 66 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 1.885968e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1885.9677431 1885.96774  0.00%     -    2s
#
# Explored 1 nodes (1 simplex iterations) in 2.01 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1885.97 1911.7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.885967743110e+03, best bound 1.885967743110e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 52337 rows, 57024 columns and 115344 nonzeros
# Model fingerprint: 0x0a774aec
# Variable types: 47520 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 7e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e-02, 5e+01]
# Found heuristic solution: objective 3558.2485185
# Presolve removed 52336 rows and 56931 columns
# Presolve time: 1.81s
# Presolved: 1 rows, 93 columns, 93 nonzeros
# Found heuristic solution: objective 3472.4967964
# Variable types: 93 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 3.471354e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3471.3537171 3471.35372  0.00%     -    1s
#
# Explored 1 nodes (1 simplex iterations) in 1.85 seconds (0.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3471.35 3558.25
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.471353717103e+03, best bound 3.471353717103e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 33276 rows, 38016 columns and 76158 nonzeros
# Model fingerprint: 0x27f2beb1
# Variable types: 28512 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [2e-01, 4e-01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 2e+01]
# Found heuristic solution: objective 3464.2490545
# Presolve removed 33275 rows and 37981 columns
# Presolve time: 2.07s
# Presolved: 1 rows, 35 columns, 35 nonzeros
# Found heuristic solution: objective 3344.0072767
# Variable types: 35 continuous, 0 integer (0 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 2.10 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 3344.01 3464.25
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.344007276699e+03, best bound 3.343904481729e+03, gap 0.0031%

# %% [markdown]
# #### Save Data

# %%
#save as a dataframe
cost_before_shift_df = pd.DataFrame(cost_before_shift_fix, columns=['cost_before_shift'])
cost_after_shift_df = pd.DataFrame(cost_after_shift, columns=['cost_after_shift'])

#ev_after_shift.to_csv('ev_after_shift_4kappa.csv')
#hp_after_shift.to_csv('hp_after_shift_4kappa.csv')
cost_before_shift_df.to_csv('cost_before_shift.csv')
cost_after_shift_df.to_csv('cost_after_shift.csv')
load_after_shift.to_csv('load_after_shift.csv')

# %%
p_fix=np.zeros(25)
for i in range(25):
    p_fix[i]=0.3085
p_grid
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(p_fix, label="fix", color='tab:orange', linewidth=1.0)
ax.plot(p_flex.iloc[24:49,0].reset_index(drop=True)+p_grid, label="dynamic", color='tab:blue', linewidth=1.0)
ax.set_ylabel("Price per kWh")
ax.legend(labels=["fix", "dynamic"], loc="center left", bbox_to_anchor=(0.65, 0.20))
ticks = [i * 6 for i in range(5)]  # 0, 6, 12, 18, 24
labels = ['0:00', '6:00', '12:00', '18:00', '24:00']
ax.set_xticks(ticks)
ax.set_xticklabels(labels)
ax.set_xlabel('Time')
plt.savefig('Prices.png', bbox_inches='tight')
plt.show()
