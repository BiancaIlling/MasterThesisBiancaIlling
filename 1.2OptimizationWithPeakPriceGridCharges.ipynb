# %% [markdown]
# This notebook includes the calculation of volumetric grid charges with a peak price of 67.94 € and the optimization of empirical household energy consumption with flat and dynamic energy prices for this case.

# %% [markdown]
# ### Requirements

# %% [markdown]
# Load the necessary packages to complete the optimization.

# %%
import pandas as pd
import numpy as np
from gurobipy import *

# %% [markdown]
# ### Methods

# %% [markdown]
# The first method is used in the optimization to determine the start and end points of each charging session, as well as the overall charged energy within one session. The second method is used to write the results of the optimization into a dataframe, enabling further analysis.

# %%
#Function to calculate start point, end point, and total energy charged for each charging session
def chargPerUser(load,percent):
    
    #List to store information about charging sessions
    charging_sessions = []
    
    total_energy_charged = 0
    b=False
    b1=False

    #Iterate through all time steps
    for i in range(len(percent)):
        
        #If the plugin hour is not a full hour
        if percent[i] < 1 and percent[i] != 0 and b == False:
            total_energy_charged += load[i] #Add charged energy
            start_index = i #Save the start point
            b = True
            
        #If the plugin hour is a full hour   
        elif percent[i]==1 and percent[i-1]==0:
            total_energy_charged += load[i]
            start_index = i
            b = True
        
        #Full charging hour between plugin and plugout
        elif percent[i] == 1:
            total_energy_charged += load[i]
            b = True
            b1 = True
            
        #Plugout after hours of full charging and the end hour is not a full hour   
        elif percent[i] < 1 and percent[i] != 0 and b == True and b1 == True and percent[i+1] == 0:
            total_energy_charged += load[i]
            end_index = i #Save the end point
            charging_sessions.append({'start_index': start_index, 'end_index': end_index, 'total_energy': total_energy_charged})
            total_energy_charged = 0
            b = False
            b1 = False
            
        #Plugout after no hour of full charging and the end hour is not a full hour 
        elif percent[i] < 1 and percent[i] != 0 and b == True and b1 == False and percent[i+1] == 0:
            total_energy_charged += load[i]
            end_index = i
            charging_sessions.append({'start_index': start_index, 'end_index': end_index, 'total_energy': total_energy_charged})
            total_energy_charged = 0
            b = False
            
        #Plugout in the same hour as plugin
        elif percent[i] == 0 and b == True and b1 == False:
            end_index = start_index
            charging_sessions.append({'start_index': start_index, 'end_index': end_index, 'total_energy': total_energy_charged})
            total_energy_charged = 0
            b = False
        
        #Plugout after hours of full charging and the end hour is a full hour 
        elif percent[i] == 0 and b == True and b1 == True:
            end_index = i-1
            charging_sessions.append({'start_index': start_index, 'end_index': end_index, 'total_energy': total_energy_charged})
            total_energy_charged = 0 
            b = False
            b1 = False
        
        #If no energy is charged or if several not full hours follow each other
        else:
            total_energy_charged += load[i]
            
    return(charging_sessions)

# %%
#Write resluts of optimization in dataframe
def get_results_in_df(variableNames, n_timesteps, model):
   

    results_df = pd.DataFrame(columns = variableNames, index = [t for t in range(n_timesteps)] )   #An empty DataFrame is created here, with column entries as the names of the Gurobi variables and rows as the time steps of the decision variables

    for n in variableNames:                                         #Iterate over all target variables
        for t in range(n_timesteps):                                #Iterate over all time steps
            VarName = n + f"[{t}]"                                  #Create a string in the form n[t]. This will be used to read the target variable later
            try:                                                    #If an error occurs in the next line, e.g., due to a typo in my target variables, the function will not stop but continue to execute
                results_df.loc[t][n] =  model.getVarByName(VarName).x    #Read the target variable
            except:
                pass
            
    return results_df

# %% [markdown]
# ### Dictionaries

# %% [markdown]
# The following dictionaries are used to reference column names by indexing:

# %%
#Dictionary for households
hh_dic={1:"SFH3_HH",2:"SFH4_HH",3:"SFH5_HH",4:"SFH7_HH",5:"SFH9_HH",6:"SFH12_HH",7:"SFH14_HH",8:"SFH16_HH",9:"SFH18_HH",10:"SFH19_HH",
        11:"SFH20_HH",12:"SFH21_HH",13:"SFH22_HH",14:"SFH27_HH",15:"SFH28_HH",16:"SFH29_HH",17:"SFH30_HH",18:"SFH32_HH",19:"SFH34_HH",
        20:"SFH36_HH",21:"SFH38_HH",22:"SFH39_HH"}

# %%
#Dictionary for heatpumps
hp_dic={1:"SFH3_HP",2:"SFH4_HP",3:"SFH5_HP",4:"SFH7_HP",5:"SFH9_HP",6:"SFH12_HP",7:"SFH14_HP",8:"SFH16_HP",9:"SFH18_HP",10:"SFH19_HP",
        11:"SFH20_HP",12:"SFH21_HP",13:"SFH22_HP",14:"SFH27_HP",15:"SFH28_HP",16:"SFH29_HP",17:"SFH30_HP",18:"SFH32_HP",19:"SFH34_HP",
        20:"SFH36_HP",21:"SFH38_HP",22:"SFH39_HP"}

# %% [markdown]
# ### Optimization

# %% [markdown]
# The following method describes the optimization of empirical household consumption with volumetric grid charges and additional peak price grid charges to minimize total costs. HH consumption remains inflexible. Shifting HP consumption is restricted by a maximum number of blocked time steps (sigma_max) in each interval of length 'length'. The total consumption over an interval must match the empirical consumption within that interval. EV shifting is freely possible between plug-in and plug-out times, as long as the maximum charging power (ev_max) of the wallbox is not surpassed and the charged energy for the session matches the empirical data.

# %%
#Optimization of one household with hp flexibility within intervals and flexible ev between plugin and plugout without dynamic energy prices
def optimized_HP_EV_flat(hh, hp, ev_user, peak_ev, flexibility, length, p_flex, p_grid, p_peak):
    
    l = len(hh)
    l_ev= len(ev_user.columns)//2
    ev_max = peak_ev
    hp_max = max(hp)
    sigma_max = flexibility
    part = length
    
    #1. create Model
    model  = Model("simpleHP")
        

    #2. define Variables
    
    #2.1 hp load over all time steps
    d_hp = model.addVars(l, vtype=GRB.CONTINUOUS, lb=0, ub=hp_max, name="d_hp")
    
    #2.2 procentual hp shifts over all time steps
    sigma = model.addVars(l,vtype=GRB.BINARY, name="sigma")
    
    #2.3 ev charging load over all time steps
    d_ev = model.addVars(l, l_ev, vtype=GRB.CONTINUOUS, lb=0, ub=ev_max, name="d_ev")
    
    #2.4 total consumption over all time steps
    d = model.addVars(l, vtype=GRB.CONTINUOUS, lb=0, name="d")

    #2.5 peak demand over time period
    max_net_energy = model.addVar(name="max_net_energy")
    

    #3. constraints
    
    #3.1 total consumption over all time steps as sum of hp, hh and all evs
    model.addConstrs(d[t] == d_hp[t]+hh[t]+quicksum(d_ev[t,u] for u in range(l_ev)) for t in range(l))
    
    #HP
    #3.2 calculation of hp load
    model.addConstrs(d_hp[t] >= (1-sigma[t])*hp[t] for t in range(l))
    
    #3.3 hp flexibility is restricted to flex_hours through binary variable sigma
    model.addConstrs(quicksum(sigma[k] for k in range(part*i,part*i+part)) <= sigma_max for i in range(l//part))

    #3.4 hp load over time part must at least be empirical hp
    model.addConstrs(quicksum(d_hp[k] for k in range(part*i,part*i+part)) >= quicksum(hp[k] for k in range(part*i,part*i+part)) for i in range(l//part))

    
    #EV
    #iterate through all evs (users) that charge at this garage
    for u in range(l_ev):
        ev = ev_user.iloc[:,u*2]
        ev_perc = ev_user.iloc[:,u*2+1]
        
        #3.5 in every timestep ev power demand must be smaller than ev_max
        model.addConstrs(d_ev[t,u] <= ev_perc[t]*ev_max for t in range(l))
        
        #get for every charging session start and end time and the total charged energy
        charging_sessions=chargPerUser(ev,ev_perc)
        list_length = len(charging_sessions)
        
        #iterate through all charging sessions of one user
        for i in range (list_length):
            start_index = charging_sessions[i]['start_index']
            end_index = charging_sessions[i]['end_index']
            total_energy = charging_sessions[i]['total_energy']
            
            #3.6 the charged power between start and end must be equal to the total charged energy
            model.addConstr(quicksum(d_ev[t,u] for t in range(start_index,end_index+1)) == total_energy)

    #determine peak
    for t in range(l):
        model.addConstr(max_net_energy >= d[t], name=f"max_constraint_{t}")

            
    #4. optimize
    objective_expr = quicksum(d[t] * (p_flex+p_grid) for t in range(l))#(p_flex.iloc[t,0]+p_grid) for t in range(l))
    
    #4.1 set the costs as the variable to be minimized
    model.setObjective(objective_expr+max_net_energy*p_peak,GRB.MINIMIZE)

    #4.2 perform optimization
    model.optimize()
    
    #5 return results
    #5.1 get objective value
    cost = model.getObjective().getValue()
    
    #get values for total load d for every hour
    var =["d"]
    load_after_shift = get_results_in_df(var,l, model)
    
    return cost, load_after_shift

# %%
#Optimization of one household with hp flexibility within intervals and flexible ev between plugin and plugout with dynamic energy prices
def optimized_HP_EV(hh, hp, ev_user, peak_ev, flexibility, length, p_flex, p_grid, p_peak):
    
    l = len(hh)
    l_ev= len(ev_user.columns)//2
    ev_max = peak_ev
    hp_max = max(hp)
    sigma_max = flexibility
    part = length
    
    #1. create Model
    model  = Model("simpleHP")
        

    #2. define Variables
    
    #2.1 hp load over all time steps
    d_hp = model.addVars(l, vtype=GRB.CONTINUOUS, lb=0, ub=hp_max, name="d_hp")
    
    #2.2 procentual hp shifts over all time steps
    sigma = model.addVars(l,vtype=GRB.BINARY, name="sigma")
    
    #2.3 ev charging load over all time steps
    d_ev = model.addVars(l, l_ev, vtype=GRB.CONTINUOUS, lb=0, ub=ev_max, name="d_ev")
    
    #2.4 total consumption over all time steps
    d = model.addVars(l, vtype=GRB.CONTINUOUS, lb=0, name="d")

    #2.5 peak demand over time period
    max_net_energy = model.addVar(name="max_net_energy")
    

    #3. constraints
    
    #3.1 total consumption over all time steps as sum of hp, hh and all evs
    model.addConstrs(d[t] == d_hp[t]+hh[t]+quicksum(d_ev[t,u] for u in range(l_ev)) for t in range(l))
    
    #HP
    #3.2 calculation of hp load
    model.addConstrs(d_hp[t] >= (1-sigma[t])*hp[t] for t in range(l))
    
    #3.3 hp flexibility is restricted to flex_hours through binary variable sigma
    model.addConstrs(quicksum(sigma[k] for k in range(part*i,part*i+part)) <= sigma_max for i in range(l//part))

    #3.4 hp load over time part must at least be empirical hp
    model.addConstrs(quicksum(d_hp[k] for k in range(part*i,part*i+part)) >= quicksum(hp[k] for k in range(part*i,part*i+part)) for i in range(l//part))

    
    #EV
    #iterate through all evs (users) that charge at this garage
    for u in range(l_ev):
        ev = ev_user.iloc[:,u*2]
        ev_perc = ev_user.iloc[:,u*2+1]
        
        #3.5 in every timestep ev power demand must be smaller than ev_max
        model.addConstrs(d_ev[t,u] <= ev_perc[t]*ev_max for t in range(l))
        
        #get for every charging session start and end time and the total charged energy
        charging_sessions=chargPerUser(ev,ev_perc)
        list_length = len(charging_sessions)
        
        #iterate through all charging sessions of one user
        for i in range (list_length):
            start_index = charging_sessions[i]['start_index']
            end_index = charging_sessions[i]['end_index']
            total_energy = charging_sessions[i]['total_energy']
            
            #3.6 the charged power between start and end must be equal to the total charged energy
            model.addConstr(quicksum(d_ev[t,u] for t in range(start_index,end_index+1)) == total_energy)

    #determine peak
    for t in range(l):
        model.addConstr(max_net_energy >= d[t], name=f"max_constraint_{t}")

            
    #4. optimize
    objective_expr = quicksum(d[t] * (p_flex.iloc[t,0]+p_grid) for t in range(l))
    
    #4.1 set the costs as the variable to be minimized
    model.setObjective(objective_expr+max_net_energy*p_peak,GRB.MINIMIZE)

    #4.2 perform optimization
    model.optimize()
    
    #5 return results
    #5.1 get objective value
    cost = model.getObjective().getValue()
    
    #get values for total load d for every hour
    var =["d"]
    load_after_shift = get_results_in_df(var,l, model)
    
    return cost, load_after_shift

# %% [markdown]
# ### Read in data

# %% [markdown]
# Read in EV charging data, household and heat pump consumption patterns, day-ahead market prices, garage IDs, total load in the empirical case, as well as the costs in the empirical scenario. All data has been pre-processed beforehand.

# %%
ev_hourly = pd.read_csv('Hourly_EV_Charging.csv') #Charging data
hh_hp = pd.read_csv('Hourly_HH_HP.csv') #Hourly HP and HH consumption patterns
peak_ev = pd.read_csv('Min_Peak_Load.csv') #Maximum charging power of each charging station
p_flex = pd.read_csv('Hourly_Flexible_Prices.csv') #Day-ahead market prices
unique_garage = pd.read_csv('Unique_Garage.csv') #Garage IDs
load_before_shift = pd.read_csv('load_before_shift.csv',index_col=0) #empirical total load
cost_before_shift_flat = pd.read_csv('cost_before_shift.csv',index_col=0) #costs with volumetric grid charges and empirical consumption

# %%
p_grid_alt=0.2695 #grid charges per kWh in case of only volumetric grid charges
p_peak = 67.94 #prices for highest peak over the observation period

# %% [markdown]
# Calculate costs before shift with peak pricing to determine the volumetric grid charges in the case of addtional peak pricing

# %%
#Calculate costs with empirical data, the grid charges of the volumetric case (used in the scenario before) and the additional peak price
cost_before_shift_peak = []

for i in range(len(peak_ev)): #Iterate over all HHs and determine total costs for each HH with empirical consumption patterns
    
    cost = 0
    max_load= load_before_shift.iloc[:,i].max()
    
    for k in range(len(p_flex)):
        cost += load_before_shift.iloc[k,i]*(p_flex.iloc[k,0]+p_grid_alt)
        
    cost_before_shift_peak.append(cost+p_peak*max_load)

# %%
#Calculate costs per kWh first in the case of only volumetric grid charges and then in the case of volumetric grid charges with additional peak pricing
c_per_kWh_flat = (cost_before_shift_flat.sum()/load_before_shift.sum().sum()).item()
c_per_kWh_peak=(sum(cost_before_shift_peak)/load_before_shift.sum().sum()).item()
#determine the difference between the two cases and with it the new grid charges in case of additional peak pricing
diff= c_per_kWh_flat-c_per_kWh_peak
p_grid = p_grid_alt+diff

# %% [markdown]
# Calculate the energy costs per kWh in case of flat energy tariff in combination with volumetric grid charges with additional peak pricing

# %%
cost_before_shift_peak_p_flat = []

for i in range(len(peak_ev)): #Iterate over all HHs and calculate total costs with empirical consumption patterns
    cost = 0
    max_load= load_before_shift.iloc[:,i].max()
    for k in range(len(p_flex)):
        cost += load_before_shift.iloc[k,i]*(p_grid)
    cost_before_shift_peak_p_flat.append(cost+p_peak*max_load)

# %%
p_flat = (sum(cost_before_shift_flat['cost_before_shift'].tolist())-sum(cost_before_shift_peak_p_flat))/load_before_shift.sum().sum()

# %% [markdown]
# ### Perform optimization

# %% [markdown]
# Perform optimization for each HH, first for flat energy prices and then for dynamic energy prices, to determine the new household consumption patterns for each scenario.

# %%
load_after_shift_p_flat = pd.DataFrame()
cost_after_shift_p_flat = []
#p_flat = 0.038977773713860416

#Iterate over all households
for i in range(len(peak_ev)):
    
    #Select all users per garage
    selected_columns = ev_hourly.filter(regex=f'^{unique_garage.iloc[i,0]}-', axis=1)
    
    #Perform optimization
    cost, load = optimized_HP_EV_flat(hh_hp[hh_dic[i+1]],hh_hp[hp_dic[i+1]], selected_columns, peak_ev.iloc[i,0],2,4, p_flat, p_grid,p_peak)
    
    #Save total costs
    cost_after_shift_p_flat.append(cost)
    
    #Store shifted loads per household
    load_after_shift_p_flat[f"{hh_dic[i+1]}_d"] = load.iloc[:,0]
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-01-31
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 62069 rows, 57025 columns and 137826 nonzeros
# Model fingerprint: 0x1eeef6e8
# Variable types: 47521 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 4e+01]
# Found heuristic solution: objective 3827.7669799
# Presolve removed 53571 rows and 46075 columns
# Presolve time: 0.38s
# Presolved: 8498 rows, 10950 columns, 28366 nonzeros
# Found heuristic solution: objective 3811.4743596
# Variable types: 7446 continuous, 3504 integer (3504 binary)
#
# Root relaxation: objective 2.817590e+03, 4455 iterations, 0.02 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2817.59033    0    2 3811.47436 2817.59033  26.1%     -    0s
# H    0     0                    2817.6046499 2817.59033  0.00%     -    0s
#
# Explored 1 nodes (4455 simplex iterations) in 0.48 seconds (0.23 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2817.6 3811.47 3827.77
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.817604649871e+03, best bound 2.817590326298e+03, gap 0.0005%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 110757 rows, 104545 columns and 249739 nonzeros
# Model fingerprint: 0x87b709c9
# Variable types: 95041 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 5e+01]
# Found heuristic solution: objective 9693.3875167
# Presolve removed 89880 rows and 67529 columns
# Presolve time: 0.28s
# Presolved: 20877 rows, 37016 columns, 89081 nonzeros
# Found heuristic solution: objective 9647.1682212
# Variable types: 28932 continuous, 8084 integer (8084 binary)
#
# Root relaxation: objective 7.228598e+03, 12208 iterations, 0.06 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7228.59754    0    2 9647.16822 7228.59754  25.1%     -    0s
# H    0     0                    7284.6561377 7228.59754  0.77%     -    0s
# H    0     0                    7228.5975358 7228.59754  0.00%     -    0s
#      0     0 7228.59754    0    2 7228.59754 7228.59754  0.00%     -    0s
#
# Explored 1 nodes (12208 simplex iterations) in 0.53 seconds (0.46 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 7228.6 7284.66 9647.17 9693.39
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.228597535754e+03, best bound 7.228597535754e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 71813 rows, 66529 columns and 162067 nonzeros
# Model fingerprint: 0x2a2c7dc1
# Variable types: 57025 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 6e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [2e-03, 8e+01]
# Found heuristic solution: objective 6678.9844783
# Presolve removed 57588 rows and 46924 columns
# Presolve time: 0.30s
# Presolved: 14225 rows, 19605 columns, 50332 nonzeros
# Found heuristic solution: objective 6664.9177898
# Variable types: 13865 continuous, 5740 integer (5740 binary)
#
# Root relaxation: objective 5.597177e+03, 8159 iterations, 0.04 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5597.17674    0    4 6664.91779 5597.17674  16.0%     -    0s
# H    0     0                    5650.5434403 5597.17674  0.94%     -    0s
# H    0     0                    5597.1767380 5597.17674  0.00%     -    0s
#      0     0 5597.17674    0    4 5597.17674 5597.17674  0.00%     -    0s
#
# Explored 1 nodes (8159 simplex iterations) in 0.47 seconds (0.30 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 5597.18 5650.54 6664.92 6678.98
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.597176738019e+03, best bound 5.597176738019e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42974 rows, 38017 columns and 98930 nonzeros
# Model fingerprint: 0xdf809321
# Variable types: 28513 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e-02, 2e+01]
# Found heuristic solution: objective 3250.9896158
# Presolve removed 36866 rows and 31143 columns
# Presolve time: 0.37s
# Presolved: 6108 rows, 6874 columns, 19941 nonzeros
# Found heuristic solution: objective 3242.4158836
# Variable types: 4342 continuous, 2532 integer (2532 binary)
#
# Root relaxation: objective 2.895372e+03, 3072 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2895.3719384 2895.37194  0.00%     -    0s
#
# Explored 1 nodes (3072 simplex iterations) in 0.42 seconds (0.16 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2895.37 3242.42 3250.99
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.895371938394e+03, best bound 2.895371938394e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42786 rows, 38017 columns and 95295 nonzeros
# Model fingerprint: 0x05dc3c07
# Variable types: 28513 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 3e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 6e+01]
# Found heuristic solution: objective 4376.8876886
# Presolve removed 42110 rows and 37204 columns
# Presolve time: 0.43s
# Presolved: 676 rows, 813 columns, 2089 nonzeros
# Found heuristic solution: objective 4361.9949531
# Variable types: 529 continuous, 284 integer (284 binary)
#
# Root relaxation: objective 4.093718e+03, 431 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    4093.7178753 4093.71788  0.00%     -    0s
#
# Explored 1 nodes (431 simplex iterations) in 0.46 seconds (0.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4093.72 4361.99 4376.89
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.093717875274e+03, best bound 4.093717875274e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 52363 rows, 47521 columns and 115192 nonzeros
# Model fingerprint: 0xe5e2eb60
# Variable types: 38017 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 7e+01]
# Found heuristic solution: objective 3700.2653766
# Presolve removed 51856 rows and 46862 columns
# Presolve time: 0.43s
# Presolved: 507 rows, 659 columns, 1673 nonzeros
# Found heuristic solution: objective 3667.3132208
# Variable types: 443 continuous, 216 integer (216 binary)
#
# Root relaxation: objective 3.207848e+03, 328 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3207.8479772 3207.84798  0.00%     -    0s
#
# Explored 1 nodes (328 simplex iterations) in 0.47 seconds (0.12 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3207.85 3667.31 3700.27
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.207847977241e+03, best bound 3.207847977241e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 61953 rows, 57025 columns and 136284 nonzeros
# Model fingerprint: 0xdf591113
# Variable types: 47521 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 9e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 9e+00]
#   RHS range        [1e-02, 7e+01]
# Found heuristic solution: objective 5803.0134540
# Presolve removed 50334 rows and 44890 columns
# Presolve time: 0.30s
# Presolved: 11619 rows, 12135 columns, 35681 nonzeros
# Found heuristic solution: objective 5787.7290225
# Variable types: 7467 continuous, 4668 integer (4668 binary)
#
# Root relaxation: objective 4.726556e+03, 5657 iterations, 0.02 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4726.55611    0    6 5787.72902 4726.55611  18.3%     -    0s
# H    0     0                    4804.2758860 4726.55611  1.62%     -    0s
# H    0     0                    4726.5561097 4726.55611  0.00%     -    0s
#      0     0 4726.55611    0    6 4726.55611 4726.55611  0.00%     -    0s
#
# Explored 1 nodes (5657 simplex iterations) in 0.42 seconds (0.23 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 4726.56 4804.28 5787.73 5803.01
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.726556109729e+03, best bound 4.726556109729e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 52363 rows, 47521 columns and 115163 nonzeros
# Model fingerprint: 0x10c75469
# Variable types: 38017 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 7e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 2e+01]
# Found heuristic solution: objective 2525.6298591
# Presolve removed 47719 rows and 42654 columns
# Presolve time: 0.36s
# Presolved: 4644 rows, 4867 columns, 14660 nonzeros
# Found heuristic solution: objective 2521.6331894
# Variable types: 2959 continuous, 1908 integer (1908 binary)
#
# Root relaxation: objective 2.071188e+03, 2390 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2071.1878091 2071.18781  0.00%     -    0s
#
# Explored 1 nodes (2390 simplex iterations) in 0.42 seconds (0.16 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2071.19 2521.63 2525.63
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.071187809110e+03, best bound 2.071187809110e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 81000 rows, 76033 columns and 173952 nonzeros
# Model fingerprint: 0xc4b8d1be
# Variable types: 66529 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 8e+01]
# Found heuristic solution: objective 3993.4916830
# Presolve removed 80233 rows and 74793 columns
# Presolve time: 0.43s
# Presolved: 767 rows, 1240 columns, 2950 nonzeros
# Found heuristic solution: objective 3977.2866295
# Variable types: 928 continuous, 312 integer (312 binary)
#
# Root relaxation: objective 3.033407e+03, 483 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3033.4066021 3033.40660  0.00%     -    0s
#
# Explored 1 nodes (483 simplex iterations) in 0.48 seconds (0.17 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3033.41 3977.29 3993.49
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.033406602063e+03, best bound 3.033406602063e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 52440 rows, 47521 columns and 116541 nonzeros
# Model fingerprint: 0x627a1be4
# Variable types: 38017 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 3e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 7e+01]
# Found heuristic solution: objective 3378.9078024
# Presolve removed 49581 rows and 43777 columns
# Presolve time: 0.38s
# Presolved: 2859 rows, 3744 columns, 9574 nonzeros
# Found heuristic solution: objective 3373.4987814
# Variable types: 2560 continuous, 1184 integer (1184 binary)
#
# Root relaxation: objective 2.917453e+03, 1472 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2917.4530939 2917.45309  0.00%     -    0s
#
# Explored 1 nodes (1472 simplex iterations) in 0.43 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2917.45 3373.5 3378.91
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.917453093941e+03, best bound 2.917453093941e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 52396 rows, 47521 columns and 115520 nonzeros
# Model fingerprint: 0x2fc1f097
# Variable types: 38017 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+01]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 1e+01]
#   RHS range        [7e-02, 6e+01]
# Found heuristic solution: objective 7611.2880648
# Presolve removed 40165 rows and 36283 columns
# Presolve time: 0.26s
# Presolved: 12231 rows, 11238 columns, 32912 nonzeros
# Found heuristic solution: objective 7603.8762426
# Variable types: 6338 continuous, 4900 integer (4900 binary)
#
# Root relaxation: objective 6.407219e+03, 5769 iterations, 0.02 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    6407.2190185 2331.53956  63.6%     -    0s
#      0     0          -    0      6407.21902 6407.21902  0.00%     -    0s
#
# Explored 1 nodes (7453 simplex iterations) in 0.36 seconds (0.22 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 6407.22 7603.88 7611.29
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.407219018519e+03, best bound 6.407219018519e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 52448 rows, 47521 columns and 117382 nonzeros
# Model fingerprint: 0x2ae4578c
# Variable types: 38017 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 6e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [6e-02, 2e+01]
# Found heuristic solution: objective 3375.5529622
# Presolve removed 43999 rows and 37506 columns
# Presolve time: 0.33s
# Presolved: 8449 rows, 10015 columns, 27439 nonzeros
# Found heuristic solution: objective 3369.2558757
# Variable types: 6591 continuous, 3424 integer (3424 binary)
#
# Root relaxation: objective 3.034347e+03, 4440 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3034.34711    0    4 3369.25588 3034.34711  9.94%     -    0s
# H    0     0                    3065.3590456 3034.34711  1.01%     -    0s
# H    0     0                    3065.1543572 3034.34711  1.01%     -    0s
#      0     0 3034.34711    0    4 3065.15436 3034.34711  1.01%     -    0s
#      0     0 3039.16442    0    1 3065.15436 3039.16442  0.85%     -    0s
# *    0     0               0    3039.1644249 3039.16442  0.00%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 1
#   MIR: 2
#
# Explored 1 nodes (5329 simplex iterations) in 0.50 seconds (0.27 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 3039.16 3065.15 3065.36 ... 3375.55
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.039164424876e+03, best bound 3.039164424876e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 52401 rows, 47521 columns and 117790 nonzeros
# Model fingerprint: 0xe12ea60d
# Variable types: 38017 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e-02, 2e+01]
# Found heuristic solution: objective 5205.7380764
# Presolve removed 47934 rows and 41632 columns
# Presolve time: 0.39s
# Presolved: 4467 rows, 5889 columns, 14943 nonzeros
# Found heuristic solution: objective 5171.4228992
# Variable types: 3985 continuous, 1904 integer (1904 binary)
#
# Root relaxation: objective 4.675571e+03, 2211 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    4675.5709386 4675.57094  0.00%     -    0s
#
# Explored 1 nodes (2211 simplex iterations) in 0.45 seconds (0.15 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4675.57 5171.42 5205.74
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.675570938555e+03, best bound 4.675570938555e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42876 rows, 38017 columns and 96901 nonzeros
# Model fingerprint: 0x32efb1e7
# Variable types: 28513 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [5e-04, 4e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [5e-04, 3e+01]
# Found heuristic solution: objective 1583.4300443
# Presolve removed 37126 rows and 31717 columns
# Presolve time: 0.38s
# Presolved: 5750 rows, 6300 columns, 17259 nonzeros
# Found heuristic solution: objective 1579.9259462
# Variable types: 3952 continuous, 2348 integer (2348 binary)
#
# Root relaxation: objective 1.470644e+03, 2713 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1470.64440    0    7 1579.92595 1470.64440  6.92%     -    0s
# H    0     0                    1482.4870818 1470.64440  0.80%     -    0s
# H    0     0                    1473.5567241 1470.64440  0.20%     -    0s
# H    0     0                    1473.4378784 1470.64440  0.19%     -    0s
# *    0     0               0    1470.6444030 1470.64440  0.00%     -    0s
#
# Cutting planes:
#   Learned: 2
#   MIR: 1
#
# Explored 1 nodes (2720 simplex iterations) in 0.52 seconds (0.19 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 1470.64 1473.44 1473.56 ... 1583.43
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.470644403045e+03, best bound 1.470644403045e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42838 rows, 38017 columns and 96011 nonzeros
# Model fingerprint: 0x7df41351
# Variable types: 28513 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e-02, 4e+01]
# Found heuristic solution: objective 4097.1462973
# Presolve removed 40751 rows and 35538 columns
# Presolve time: 0.41s
# Presolved: 2087 rows, 2479 columns, 6383 nonzeros
# Found heuristic solution: objective 4061.9627923
# Variable types: 1547 continuous, 932 integer (932 binary)
#
# Root relaxation: objective 3.701540e+03, 1059 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3701.53956    0    2 4061.96279 3701.53956  8.87%     -    0s
# H    0     0                    3701.5873005 3701.53956  0.00%     -    0s
#
# Explored 1 nodes (1059 simplex iterations) in 0.46 seconds (0.12 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3701.59 4061.96 4097.15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.701587300541e+03, best bound 3.701539558647e+03, gap 0.0013%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 71570 rows, 66529 columns and 156176 nonzeros
# Model fingerprint: 0xc687cc2f
# Variable types: 57025 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 5e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [6e-04, 3e+01]
# Found heuristic solution: objective 3220.7307743
# Presolve removed 69073 rows and 62640 columns
# Presolve time: 0.45s
# Presolved: 2497 rows, 3889 columns, 9475 nonzeros
# Found heuristic solution: objective 3201.2171910
# Variable types: 2905 continuous, 984 integer (984 binary)
#
# Root relaxation: objective 2.664917e+03, 1256 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2664.9173872 2664.91739  0.00%     -    0s
#
# Explored 1 nodes (1256 simplex iterations) in 0.50 seconds (0.17 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2664.92 3201.22 3220.73
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.664917387234e+03, best bound 2.664917387234e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 71369 rows, 66529 columns and 153490 nonzeros
# Model fingerprint: 0xeea7a5b5
# Variable types: 57025 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 5e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [6e-04, 4e+01]
# Found heuristic solution: objective 2743.2669042
# Presolve removed 67158 rows and 61735 columns
# Presolve time: 0.42s
# Presolved: 4211 rows, 4794 columns, 12978 nonzeros
# Found heuristic solution: objective 2738.9797053
# Variable types: 3062 continuous, 1732 integer (1732 binary)
#
# Root relaxation: objective 1.843430e+03, 2150 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1843.42972    0    2 2738.97971 1843.42972  32.7%     -    0s
# H    0     0                    1843.6223249 1843.42972  0.01%     -    0s
# H    0     0                    1843.4297171 1843.42972  0.00%     -    0s
#      0     0 1843.42972    0    2 1843.42972 1843.42972  0.00%     -    0s
#
# Explored 1 nodes (2150 simplex iterations) in 0.50 seconds (0.19 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 1843.43 1843.62 2738.98 2743.27
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.843429717081e+03, best bound 1.843429717081e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 61964 rows, 57025 columns and 136360 nonzeros
# Model fingerprint: 0xcd38f904
# Variable types: 47521 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 4e+01]
# Found heuristic solution: objective 3230.9351815
# Presolve removed 58379 rows and 51915 columns
# Presolve time: 0.43s
# Presolved: 3585 rows, 5110 columns, 12778 nonzeros
# Found heuristic solution: objective 3220.6480849
# Variable types: 3650 continuous, 1460 integer (1460 binary)
#
# Root relaxation: objective 2.608359e+03, 1725 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2608.3588254 2608.35883  0.00%     -    0s
#
# Explored 1 nodes (1725 simplex iterations) in 0.47 seconds (0.15 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2608.36 3220.65 3230.94
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.608358825409e+03, best bound 2.608358825409e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42794 rows, 38017 columns and 95380 nonzeros
# Model fingerprint: 0x3fb3c477
# Variable types: 28513 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 6e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e-03, 3e+01]
# Found heuristic solution: objective 4470.4603239
# Presolve removed 31731 rows and 28826 columns
# Presolve time: 0.26s
# Presolved: 11063 rows, 9191 columns, 31244 nonzeros
# Found heuristic solution: objective 4462.3667333
# Variable types: 4763 continuous, 4428 integer (4428 binary)
#
# Root relaxation: objective 4.169538e+03, 4225 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4169.53788    0    2 4462.36673 4169.53788  6.56%     -    0s
# H    0     0                    4172.6588922 4169.53788  0.07%     -    0s
# H    0     0                    4172.6473696 4169.53788  0.07%     -    0s
#      0     0     cutoff    0      4172.64737 4172.64737  0.00%     -    0s
#
# Cutting planes:
#   Learned: 1
#   MIR: 1
#   Relax-and-lift: 19
#
# Explored 1 nodes (6647 simplex iterations) in 0.46 seconds (0.28 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 4172.65 4172.66 4462.37 4470.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.172647369608e+03, best bound 4.172647369608e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42801 rows, 38017 columns and 95911 nonzeros
# Model fingerprint: 0x414825ad
# Variable types: 28513 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 6e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [9e-04, 6e+01]
# Found heuristic solution: objective 2218.7880955
# Presolve removed 42786 rows and 38000 columns
# Presolve time: 0.52s
# Presolved: 15 rows, 17 columns, 40 nonzeros
# Found heuristic solution: objective 2208.2239442
# Variable types: 9 continuous, 8 integer (8 binary)
#
# Root relaxation: objective 2.092664e+03, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2092.6636523 2092.66365  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.54 seconds (0.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2092.66 2208.22 2218.79
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.092663652337e+03, best bound 2.092663652337e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 61841 rows, 57025 columns and 134352 nonzeros
# Model fingerprint: 0x14de447f
# Variable types: 47521 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 7e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e-02, 5e+01]
# Found heuristic solution: objective 4275.1140469
# Presolve removed 59755 rows and 54090 columns
# Presolve time: 0.49s
# Presolved: 2086 rows, 2935 columns, 7438 nonzeros
# Found heuristic solution: objective 4244.8341653
# Variable types: 2095 continuous, 840 integer (840 binary)
#
# Root relaxation: objective 3.462537e+03, 1040 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3462.53741    0    2 4244.83417 3462.53741  18.4%     -    0s
# H    0     0                    3569.5724906 3462.53741  3.00%     -    0s
# H    0     0                    3462.5374104 3462.53741  0.00%     -    0s
#      0     0 3462.53741    0    2 3462.53741 3462.53741  0.00%     -    0s
#
# Explored 1 nodes (1040 simplex iterations) in 0.54 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 3462.54 3569.57 4244.83 4275.11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.462537410399e+03, best bound 3.462537410399e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42780 rows, 38017 columns and 95166 nonzeros
# Model fingerprint: 0x2fc403cd
# Variable types: 28513 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 2e+01]
# Found heuristic solution: objective 3661.6377493
# Presolve removed 41614 rows and 36719 columns
# Presolve time: 0.47s
# Presolved: 1166 rows, 1298 columns, 3305 nonzeros
# Found heuristic solution: objective 3616.7321429
# Variable types: 710 continuous, 588 integer (588 binary)
#
# Root relaxation: objective 3.239099e+03, 644 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3239.09945    0    5 3616.73214 3239.09945  10.4%     -    0s
# H    0     0                    3272.3130062 3239.09945  1.01%     -    0s
#
# Cutting planes:
#   MIR: 1
#
# Explored 1 nodes (644 simplex iterations) in 0.52 seconds (0.11 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3272.31 3616.73 3661.64
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.272313006187e+03, best bound 3.272313006187e+03, gap 0.0000%

# %%
load_after_shift = pd.DataFrame()
cost_after_shift = []

#Iterate over all households
for i in range(len(peak_ev)):
    
    #Select all users per garage
    selected_columns = ev_hourly.filter(regex=f'^{unique_garage.iloc[i,0]}-', axis=1)
    
    #Perform optimization
    cost, load = optimized_HP_EV(hh_hp[hh_dic[i+1]],hh_hp[hp_dic[i+1]], selected_columns, peak_ev.iloc[i,0],2,4, p_flex, p_grid,p_peak)
    
    #Save total costs
    cost_after_shift.append(cost)
    
    #Store shifted loads per household
    load_after_shift[f"{hh_dic[i+1]}_d"] = load.iloc[:,0]
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 62069 rows, 57025 columns and 137826 nonzeros
# Model fingerprint: 0x679835b4
# Variable types: 47521 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 4e+01]
# Found heuristic solution: objective 3810.2779659
# Presolve removed 52865 rows and 45079 columns
# Presolve time: 0.87s
# Presolved: 9204 rows, 11946 columns, 30783 nonzeros
# Found heuristic solution: objective 3787.3003959
# Variable types: 8126 continuous, 3820 integer (3820 binary)
#
# Root relaxation: objective 2.750756e+03, 5773 iterations, 0.03 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2750.75569    0   30 3787.30040 2750.75569  27.4%     -    0s
# H    0     0                    2754.5200884 2750.75569  0.14%     -    1s
#      0     0 2750.75704    0    2 2754.52009 2750.75704  0.14%     -    1s
# H    0     0                    2750.8232988 2750.75704  0.00%     -    1s
#
# Cutting planes:
#   Gomory: 4
#   Implied bound: 1
#   MIR: 13
#
# Explored 1 nodes (6151 simplex iterations) in 1.11 seconds (0.27 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 2750.82 2754.52 3787.3 3810.28
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.750823298822e+03, best bound 2.750757042907e+03, gap 0.0024%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 110757 rows, 104545 columns and 249739 nonzeros
# Model fingerprint: 0x36f6bd94
# Variable types: 95041 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 5e+01]
# Found heuristic solution: objective 9660.6830260
# Presolve removed 89722 rows and 67038 columns
# Presolve time: 0.39s
# Presolved: 21035 rows, 37507 columns, 90075 nonzeros
# Found heuristic solution: objective 9609.9257323
# Variable types: 29363 continuous, 8144 integer (8144 binary)
#
# Root relaxation: objective 7.059316e+03, 15294 iterations, 0.12 seconds (0.11 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7059.31620    0   24 9609.92573 7059.31620  26.5%     -    0s
# H    0     0                    7061.4031931 7059.31620  0.03%     -    0s
# H    0     0                    7059.3204577 7059.31620  0.00%     -    0s
#
# Explored 1 nodes (16170 simplex iterations) in 0.79 seconds (0.53 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 7059.32 7061.4 9609.93 9660.68
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.059320457667e+03, best bound 7.059316197368e+03, gap 0.0001%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 71813 rows, 66529 columns and 162067 nonzeros
# Model fingerprint: 0x595db10d
# Variable types: 57025 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 6e+00]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [2e-03, 8e+01]
# Found heuristic solution: objective 6638.8649464
# Presolve removed 56284 rows and 44844 columns
# Presolve time: 0.67s
# Presolved: 15529 rows, 21685 columns, 55290 nonzeros
# Found heuristic solution: objective 6613.1067445
# Variable types: 15389 continuous, 6296 integer (6296 binary)
#
# Root relaxation: objective 5.456146e+03, 11007 iterations, 0.07 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5456.14558    0   28 6613.10674 5456.14558  17.5%     -    0s
# H    0     0                    5462.3649643 5456.14558  0.11%     -    0s
# H    0     0                    5456.1538490 5456.14558  0.00%     -    0s
#
# Explored 1 nodes (11420 simplex iterations) in 0.96 seconds (0.40 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 5456.15 5462.36 6613.11 6638.86
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.456153849025e+03, best bound 5.456145577738e+03, gap 0.0002%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42974 rows, 38017 columns and 98930 nonzeros
# Model fingerprint: 0x63ae3229
# Variable types: 28513 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e-02, 2e+01]
# Found heuristic solution: objective 3243.2247082
# Presolve removed 35554 rows and 29269 columns
# Presolve time: 1.15s
# Presolved: 7420 rows, 8748 columns, 24425 nonzeros
# Found heuristic solution: objective 3216.9714502
# Variable types: 5624 continuous, 3124 integer (3124 binary)
#
# Root relaxation: objective 2.847186e+03, 4445 iterations, 0.04 seconds (0.07 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2847.18614    0  110 3216.97145 2847.18614  11.5%     -    1s
# H    0     0                    2941.1565432 2847.18614  3.20%     -    1s
# H    0     0                    2930.2376382 2847.18614  2.83%     -    1s
# H    0     0                    2929.9512813 2847.18614  2.82%     -    1s
# H    0     0                    2898.7198611 2847.18991  1.78%     -    1s
#      0     0 2847.19662    0    4 2898.71986 2847.19662  1.78%     -    1s
# H    0     0                    2847.6511143 2847.19662  0.02%     -    1s
# H    0     0                    2847.1966619 2847.19662  0.00%     -    1s
#
# Cutting planes:
#   Learned: 2
#   Gomory: 44
#   Clique: 2
#   MIR: 30
#
# Explored 1 nodes (5031 simplex iterations) in 1.42 seconds (0.34 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 2847.2 2847.65 2898.72 ... 3243.22
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.847196661925e+03, best bound 2.847196623219e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42786 rows, 38017 columns and 95295 nonzeros
# Model fingerprint: 0xfab54306
# Variable types: 28513 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 3e+00]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 6e+01]
# Found heuristic solution: objective 4366.6727348
# Presolve removed 42110 rows and 37197 columns
# Presolve time: 1.39s
# Presolved: 676 rows, 820 columns, 2096 nonzeros
# Found heuristic solution: objective 4325.8727739
# Variable types: 536 continuous, 284 integer (284 binary)
#
# Root relaxation: objective 4.053100e+03, 524 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4053.10028    0    7 4325.87277 4053.10028  6.31%     -    1s
# H    0     0                    4053.1051798 4053.10028  0.00%     -    1s
#
# Explored 1 nodes (524 simplex iterations) in 1.43 seconds (0.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4053.11 4325.87 4366.67
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.053105179764e+03, best bound 4.053100283557e+03, gap 0.0001%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 52363 rows, 47521 columns and 115192 nonzeros
# Model fingerprint: 0x2d984bda
# Variable types: 38017 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 7e+01]
# Found heuristic solution: objective 3692.2479357
# Presolve removed 51280 rows and 45977 columns
# Presolve time: 1.66s
# Presolved: 1083 rows, 1544 columns, 3657 nonzeros
# Found heuristic solution: objective 3634.5960747
# Variable types: 1080 continuous, 464 integer (464 binary)
#
# Root relaxation: objective 3.164314e+03, 784 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3164.31416    0   18 3634.59607 3164.31416  12.9%     -    1s
# H    0     0                    3282.9673130 3164.31416  3.61%     -    1s
# H    0     0                    3164.3248838 3164.31416  0.00%     -    1s
#
# Explored 1 nodes (814 simplex iterations) in 1.71 seconds (0.16 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 3164.32 3282.97 3634.6 3692.25
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.164324883850e+03, best bound 3.164314160148e+03, gap 0.0003%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 61953 rows, 57025 columns and 136284 nonzeros
# Model fingerprint: 0x5d814474
# Variable types: 47521 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 9e+00]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 9e+00]
#   RHS range        [1e-02, 7e+01]
# Found heuristic solution: objective 5813.5585991
# Presolve removed 50018 rows and 44378 columns
# Presolve time: 0.94s
# Presolved: 11935 rows, 12647 columns, 36857 nonzeros
# Found heuristic solution: objective 5791.0737751
# Variable types: 7839 continuous, 4808 integer (4808 binary)
#
# Root relaxation: objective 4.669822e+03, 6682 iterations, 0.04 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4669.82241    0   90 5791.07378 4669.82241  19.4%     -    1s
# H    0     0                    4737.0388728 4669.82241  1.42%     -    1s
# H    0     0                    4669.8568319 4669.82241  0.00%     -    1s
#
# Explored 1 nodes (8058 simplex iterations) in 1.14 seconds (0.30 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 4669.86 4737.04 5791.07 5813.56
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.669856831919e+03, best bound 4.669822411506e+03, gap 0.0007%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 52363 rows, 47521 columns and 115163 nonzeros
# Model fingerprint: 0x3b359451
# Variable types: 38017 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 7e+00]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 2e+01]
# Found heuristic solution: objective 2539.9543158
# Presolve removed 47715 rows and 42631 columns
# Presolve time: 1.29s
# Presolved: 4648 rows, 4890 columns, 14687 nonzeros
# Found heuristic solution: objective 2529.3609195
# Variable types: 2982 continuous, 1908 integer (1908 binary)
#
# Root relaxation: objective 2.068060e+03, 2710 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2068.06032    0   48 2529.36092 2068.06032  18.2%     -    1s
# H    0     0                    2221.3881421 2068.06032  6.90%     -    1s
# H    0     0                    2221.3870888 2068.06032  6.90%     -    1s
# H    0     0                    2142.7195732 2068.06032  3.48%     -    1s
#      0     0 2068.07370    0    7 2142.71957 2068.07370  3.48%     -    1s
# H    0     0                    2068.1093936 2068.07372  0.00%     -    1s
#
# Cutting planes:
#   Gomory: 11
#   Clique: 2
#   MIR: 19
#
# Explored 1 nodes (3113 simplex iterations) in 1.43 seconds (0.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 2068.11 2142.72 2221.39 ... 2539.95
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.068109393571e+03, best bound 2.068073720776e+03, gap 0.0017%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 81000 rows, 76033 columns and 173952 nonzeros
# Model fingerprint: 0x30f61476
# Variable types: 66529 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 8e+01]
# Found heuristic solution: objective 3976.2830062
# Presolve removed 79176 rows and 72944 columns
# Presolve time: 1.44s
# Presolved: 1824 rows, 3089 columns, 7166 nonzeros
# Found heuristic solution: objective 3943.6731484
# Variable types: 2345 continuous, 744 integer (744 binary)
#
# Root relaxation: objective 2.983095e+03, 1227 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2983.09496    0    2 3943.67315 2983.09496  24.4%     -    1s
# H    0     0                    2983.0953927 2983.09496  0.00%     -    1s
#
# Explored 1 nodes (1227 simplex iterations) in 1.51 seconds (0.17 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2983.1 3943.67 3976.28
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.983095392723e+03, best bound 2.983094957905e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 52440 rows, 47521 columns and 116541 nonzeros
# Model fingerprint: 0xcdaab787
# Variable types: 38017 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 3e+00]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 7e+01]
# Found heuristic solution: objective 3369.8376598
# Presolve removed 48823 rows and 42769 columns
# Presolve time: 1.18s
# Presolved: 3617 rows, 4752 columns, 12104 nonzeros
# Found heuristic solution: objective 3351.6144966
# Variable types: 3244 continuous, 1508 integer (1508 binary)
#
# Root relaxation: objective 2.877993e+03, 2037 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2877.9930254 2877.99303  0.00%     -    1s
#
# Explored 1 nodes (2037 simplex iterations) in 1.24 seconds (0.16 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2877.99 3351.61 3369.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.877993025399e+03, best bound 2.877993025399e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 52396 rows, 47521 columns and 115520 nonzeros
# Model fingerprint: 0xd7da3819
# Variable types: 38017 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+01]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 1e+01]
#   RHS range        [7e-02, 6e+01]
# Found heuristic solution: objective 7606.8801051
# Presolve removed 40164 rows and 36277 columns
# Presolve time: 1.05s
# Presolved: 12232 rows, 11244 columns, 32919 nonzeros
# Found heuristic solution: objective 7590.3178180
# Variable types: 6344 continuous, 4900 integer (4900 binary)
#
# Root relaxation: objective 6.325469e+03, 6393 iterations, 0.03 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6325.46883    0   80 7590.31782 6325.46883  16.7%     -    1s
# H    0     0                    6498.1674574 6325.46883  2.66%     -    1s
# H    0     0                    6328.6475634 6325.46883  0.05%     -    1s
# H    0     0                    6328.6365149 6325.46883  0.05%     -    1s
# H    0     0                    6328.6353903 6325.46883  0.05%     -    1s
# H    0     0                    6328.6345495 6325.46883  0.05%     -    1s
#      0     0 6325.48633    0   10 6328.63455 6325.48633  0.05%     -    1s
# H    0     0                    6325.5021480 6325.48648  0.00%     -    1s
#
# Cutting planes:
#   Gomory: 42
#   MIR: 7
#
# Explored 1 nodes (7886 simplex iterations) in 1.38 seconds (0.33 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 6325.5 6328.63 6328.64 ... 7606.88
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.325502148025e+03, best bound 6.325486483599e+03, gap 0.0002%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 52448 rows, 47521 columns and 117382 nonzeros
# Model fingerprint: 0x2bbd09dc
# Variable types: 38017 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 6e+00]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [6e-02, 2e+01]
# Found heuristic solution: objective 3388.1800393
# Presolve removed 43998 rows and 37468 columns
# Presolve time: 1.13s
# Presolved: 8450 rows, 10053 columns, 27494 nonzeros
# Found heuristic solution: objective 3372.0705114
# Variable types: 6629 continuous, 3424 integer (3424 binary)
#
# Root relaxation: objective 3.013714e+03, 5137 iterations, 0.03 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3013.71392    0   18 3372.07051 3013.71392  10.6%     -    1s
# H    0     0                    3070.7405367 3013.71392  1.86%     -    1s
# H    0     0                    3043.2661605 3013.71392  0.97%     -    1s
#      0     0 3013.72165    0   13 3043.26616 3013.72165  0.97%     -    1s
# H    0     0                    3038.5881131 3013.72414  0.82%     -    1s
#      0     0 3013.72414    0   12 3038.58811 3013.72414  0.82%     -    1s
#      0     0 3017.68843    0   23 3038.58811 3017.68843  0.69%     -    1s
#      0     0 3018.30174    0   17 3038.58811 3018.30174  0.67%     -    1s
#      0     0 3018.30175    0   16 3038.58811 3018.30175  0.67%     -    1s
# H    0     0                    3018.3089105 3018.30594  0.00%     -    1s
#      0     0 3018.30594    0   14 3018.30891 3018.30594  0.00%     -    1s
#
# Cutting planes:
#   Gomory: 9
#   Implied bound: 1
#   MIR: 13
#   Relax-and-lift: 24
#
# Explored 1 nodes (5683 simplex iterations) in 1.49 seconds (0.38 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 3018.31 3038.59 3043.27 ... 3388.18
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.018308910462e+03, best bound 3.018305935555e+03, gap 0.0001%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 52401 rows, 47521 columns and 117790 nonzeros
# Model fingerprint: 0x332266f7
# Variable types: 38017 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e-02, 2e+01]
# Found heuristic solution: objective 5214.4535325
# Presolve removed 46158 rows and 38818 columns
# Presolve time: 1.34s
# Presolved: 6243 rows, 8703 columns, 21947 nonzeros
# Found heuristic solution: objective 5153.9157578
# Variable types: 6091 continuous, 2612 integer (2612 binary)
#
# Root relaxation: objective 4.627915e+03, 3480 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4627.91509    0   68 5153.91576 4627.91509  10.2%     -    1s
# H    0     0                    4627.9342936 4627.91509  0.00%     -    1s
#
# Explored 1 nodes (4047 simplex iterations) in 1.44 seconds (0.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4627.93 5153.92 5214.45
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.627934293617e+03, best bound 4.627915093584e+03, gap 0.0004%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42876 rows, 38017 columns and 96901 nonzeros
# Model fingerprint: 0x38339178
# Variable types: 28513 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [5e-04, 4e+00]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [5e-04, 3e+01]
# Found heuristic solution: objective 1593.4965189
# Presolve removed 37096 rows and 31650 columns
# Presolve time: 1.35s
# Presolved: 5780 rows, 6367 columns, 17375 nonzeros
# Found heuristic solution: objective 1584.4649402
# Variable types: 4003 continuous, 2364 integer (2364 binary)
#
# Root relaxation: objective 1.463782e+03, 3198 iterations, 0.02 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1463.78232    0   16 1584.46494 1463.78232  7.62%     -    1s
# H    0     0                    1475.3294846 1463.78232  0.78%     -    1s
#      0     0 1463.78358    0    6 1475.32948 1463.78358  0.78%     -    1s
# H    0     0                    1474.4158926 1463.79539  0.72%     -    1s
# *    0     0               0    1463.7974880 1463.79749  0.00%     -    1s
#
# Cutting planes:
#   Learned: 2
#   Gomory: 5
#   MIR: 6
#   Relax-and-lift: 5
#
# Explored 1 nodes (3518 simplex iterations) in 1.50 seconds (0.22 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 1463.8 1474.42 1475.33 ... 1593.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.463797488040e+03, best bound 1.463797488040e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42838 rows, 38017 columns and 96011 nonzeros
# Model fingerprint: 0xa3fa4797
# Variable types: 28513 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e-02, 4e+01]
# Found heuristic solution: objective 4120.9638315
# Presolve removed 40565 rows and 35287 columns
# Presolve time: 1.17s
# Presolved: 2273 rows, 2730 columns, 6964 nonzeros
# Found heuristic solution: objective 4061.7257934
# Variable types: 1710 continuous, 1020 integer (1020 binary)
#
# Root relaxation: objective 3.692463e+03, 1309 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3692.46322    0   24 4061.72579 3692.46322  9.09%     -    1s
# H    0     0                    3698.6459815 3692.46322  0.17%     -    1s
# H    0     0                    3698.6444087 3692.47070  0.17%     -    1s
# *    0     0               0    3692.4706996 3692.47070  0.00%     -    1s
#
# Cutting planes:
#   Gomory: 4
#   MIR: 10
#   Relax-and-lift: 2
#
# Explored 1 nodes (1445 simplex iterations) in 1.25 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 3692.47 3698.64 3698.65 ... 4120.96
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.692470699627e+03, best bound 3.692470699627e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 71570 rows, 66529 columns and 156176 nonzeros
# Model fingerprint: 0xfe22a742
# Variable types: 57025 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 5e+00]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [6e-04, 3e+01]
# Found heuristic solution: objective 3224.3172006
# Presolve removed 67231 rows and 59514 columns
# Presolve time: 1.35s
# Presolved: 4339 rows, 7015 columns, 16850 nonzeros
# Found heuristic solution: objective 3189.8246593
# Variable types: 5287 continuous, 1728 integer (1728 binary)
#
# Root relaxation: objective 2.633250e+03, 2734 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2633.25005    0    2 3189.82466 2633.25005  17.4%     -    1s
# H    0     0                    2633.2530396 2633.25005  0.00%     -    1s
#
# Explored 1 nodes (2734 simplex iterations) in 1.43 seconds (0.19 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2633.25 3189.82 3224.32
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.633253039637e+03, best bound 2.633250049763e+03, gap 0.0001%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 71369 rows, 66529 columns and 153490 nonzeros
# Model fingerprint: 0xa3ac8f85
# Variable types: 57025 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 5e+00]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [6e-04, 4e+01]
# Found heuristic solution: objective 2752.0227204
# Presolve removed 67116 rows and 61672 columns
# Presolve time: 1.17s
# Presolved: 4253 rows, 4857 columns, 13117 nonzeros
# Found heuristic solution: objective 2742.5374382
# Variable types: 3105 continuous, 1752 integer (1752 binary)
#
# Root relaxation: objective 1.830981e+03, 2382 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1830.98145    0   10 2742.53744 1830.98145  33.2%     -    1s
# H    0     0                    1833.6040002 1830.98145  0.14%     -    1s
# H    0     0                    1830.9822521 1830.98145  0.00%     -    1s
#
# Explored 1 nodes (2587 simplex iterations) in 1.26 seconds (0.20 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 1830.98 1833.6 2742.54 2752.02
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.830982252065e+03, best bound 1.830981446251e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 61964 rows, 57025 columns and 136360 nonzeros
# Model fingerprint: 0xa3c7a8c9
# Variable types: 47521 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 4e+01]
# Found heuristic solution: objective 3230.6908163
# Presolve removed 57696 rows and 50769 columns
# Presolve time: 1.44s
# Presolved: 4268 rows, 6256 columns, 15435 nonzeros
# Found heuristic solution: objective 3207.3954697
# Variable types: 4516 continuous, 1740 integer (1740 binary)
#
# Root relaxation: objective 2.576870e+03, 2591 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2576.87001    0    2 3207.39547 2576.87001  19.7%     -    1s
# H    0     0                    2577.0439356 2576.87001  0.01%     -    1s
#
# Explored 1 nodes (2591 simplex iterations) in 1.51 seconds (0.17 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2577.04 3207.4 3230.69
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.577043935640e+03, best bound 2.576870005641e+03, gap 0.0067%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42794 rows, 38017 columns and 95380 nonzeros
# Model fingerprint: 0x3a1a87d8
# Variable types: 28513 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 6e+00]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e-03, 3e+01]
# Found heuristic solution: objective 4478.6213234
# Presolve removed 31731 rows and 28826 columns
# Presolve time: 0.88s
# Presolved: 11063 rows, 9191 columns, 31244 nonzeros
# Found heuristic solution: objective 4466.1622171
# Variable types: 4763 continuous, 4428 integer (4428 binary)
#
# Root relaxation: objective 4.137571e+03, 4382 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4137.57060    0  134 4466.16222 4137.57060  7.36%     -    0s
# H    0     0                    4164.1943408 4137.57060  0.64%     -    0s
# H    0     0                    4140.7642773 4137.57060  0.08%     -    1s
# H    0     0                    4140.7528599 4138.95877  0.04%     -    1s
#      0     0 4138.95877    0    9 4140.75286 4138.95877  0.04%     -    1s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 3
#   Implied bound: 1
#   MIR: 58
#   Flow cover: 1
#   Relax-and-lift: 35
#
# Explored 1 nodes (5821 simplex iterations) in 1.12 seconds (0.26 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 4140.75 4140.76 4164.19 ... 4478.62
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.140752859904e+03, best bound 4.140703674829e+03, gap 0.0012%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42801 rows, 38017 columns and 95911 nonzeros
# Model fingerprint: 0x4cbaeb20
# Variable types: 28513 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 6e+00]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [9e-04, 6e+01]
# Found heuristic solution: objective 2233.9381116
# Presolve removed 42185 rows and 37255 columns
# Presolve time: 1.55s
# Presolved: 616 rows, 762 columns, 2067 nonzeros
# Found heuristic solution: objective 2209.9846182
# Variable types: 502 continuous, 260 integer (260 binary)
#
# Root relaxation: objective 2.092780e+03, 340 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2092.77963    0    2 2209.98462 2092.77963  5.30%     -    1s
# H    0     0                    2092.8419013 2092.77963  0.00%     -    1s
#
# Explored 1 nodes (340 simplex iterations) in 1.59 seconds (0.12 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2092.84 2209.98 2233.94
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.092841901267e+03, best bound 2.092779632116e+03, gap 0.0030%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 61841 rows, 57025 columns and 134352 nonzeros
# Model fingerprint: 0xeeca87ea
# Variable types: 47521 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 7e+00]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e-02, 5e+01]
# Found heuristic solution: objective 4278.2622777
# Presolve removed 59750 rows and 54066 columns
# Presolve time: 1.37s
# Presolved: 2091 rows, 2959 columns, 7483 nonzeros
# Found heuristic solution: objective 4226.9668056
# Variable types: 2119 continuous, 840 integer (840 binary)
#
# Root relaxation: objective 3.433301e+03, 1252 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3433.30140    0    4 4226.96681 3433.30140  18.8%     -    1s
# H    0     0                    3433.7505978 3433.30140  0.01%     -    1s
# H    0     0                    3433.3013990 3433.30140  0.00%     -    1s
#      0     0 3433.30140    0    4 3433.30140 3433.30140  0.00%     -    1s
#
# Explored 1 nodes (1252 simplex iterations) in 1.43 seconds (0.15 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 3433.3 3433.75 4226.97 4278.26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.433301399004e+03, best bound 3.433301399004e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 42780 rows, 38017 columns and 95166 nonzeros
# Model fingerprint: 0x903491fc
# Variable types: 28513 continuous, 9504 integer (9504 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 6e+00]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 2e+01]
# Found heuristic solution: objective 3662.0821405
# Presolve removed 41614 rows and 36719 columns
# Presolve time: 1.44s
# Presolved: 1166 rows, 1298 columns, 3305 nonzeros
# Found heuristic solution: objective 3591.3422045
# Variable types: 710 continuous, 588 integer (588 binary)
#
# Root relaxation: objective 3.209589e+03, 707 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3209.58921    0   15 3591.34220 3209.58921  10.6%     -    1s
# H    0     0                    3242.7370270 3209.58921  1.02%     -    1s
#      0     0 3211.93579    0   17 3242.73703 3211.93579  0.95%     -    1s
#      0     0 3211.93579    0   15 3242.73703 3211.93579  0.95%     -    1s
#
# Cutting planes:
#   Learned: 2
#   Gomory: 3
#   MIR: 8
#   Relax-and-lift: 2
#
# Explored 1 nodes (1498 simplex iterations) in 1.52 seconds (0.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3242.74 3591.34 3662.08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.242737027045e+03, best bound 3.242733864100e+03, gap 0.0001%

# %% [markdown]
# ### Save Data

# %%
#save as a dataframe
cost_after_shift_p_flat_df = pd.DataFrame(cost_after_shift_p_flat, columns=['cost_before_shift'])
cost_after_shift_df = pd.DataFrame(cost_after_shift, columns=['cost_after_shift'])

cost_after_shift_p_flat_df.to_csv('cost_after_shift_peak_flat.csv')
cost_after_shift_df.to_csv('cost_after_shift_peak_dyn.csv')
load_after_shift_p_flat.to_csv('load_after_shift_peak_flat.csv')
load_after_shift.to_csv('load_after_shift_peak_dyn.csv')
